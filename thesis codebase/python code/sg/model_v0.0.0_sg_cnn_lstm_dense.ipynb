# %%
import tensorflow as tf
keras = tf.keras
import warnings
warnings.filterwarnings("ignore")
import gensim, re
import numpy as np
import pandas as pd
import openpyxl
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences 
from tensorflow.keras.models import load_model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Embedding, Bidirectional, Dropout, Conv1D

# %%
main_data = pd.read_excel( r"C:\Users\Dhrubo\1_Thesis\data_v2\suicide_data.xlsx", sheet_name="Sheet1" )
print(main_data.columns.ravel())
posts = main_data['text'].tolist()
labels = main_data['label'].tolist()
# Out:
# ['text' 'label']

# %%
from nltk.tokenize import word_tokenize

def clean_text(data):
    all_data = list()
    final_data = list()
    stopwords_bn = ["অতএব","অথচ","অথবা","অনুযায়ী","অনেক","অনেকে","অনেকেই","অন্তত","অন্য","অবধি","অবশ্য","অর্থাত","আই","আগামী","আগে","আগেই","আছে","আজ","আদ্যভাগে","আপনার","আপনি","আবার","আমরা","আমাকে","আমাদের","আমার","আমি","আর","আরও","ই","ইত্যাদি","ইহা","উচিত","উত্তর","উনি","উপর","উপরে","এ","এঁদের","এঁরা","এই","একই","একটি","একবার","একে","এক্","এখন","এখনও","এখানে","এখানেই","এটা","এটাই","এটি","এত","এতটাই","এতে","এদের","এব","এবং","এবার","এমন","এমনকী","এমনি","এর","এরা","এল","এস","এসে","ঐ","ও","ওঁদের","ওঁর","ওঁরা","ওই","ওকে","ওখানে","ওদের","ওর","ওরা","কখনও","কত","কবে","কমনে","কয়েক","কয়েকটি","করছে","করছেন","করতে","করবে","করবেন","করলে","করলেন","করা","করাই","করায়","করার","করি","করিতে","করিয়া","করিয়ে","করে","করেই","করেছিলেন","করেছে","করেছেন","করেন","কাউকে","কাছ","কাছে","কাজ","কাজে","কারও","কারণ","কি","কিংবা","কিছু","কিছুই","কিন্তু","কী","কে","কেউ","কেউই","কেখা","কেন","কোটি","কোন","কোনও","কোনো","ক্ষেত্রে","কয়েক","খুব","গিয়ে","গিয়েছে","গিয়ে","গুলি","গেছে","গেল","গেলে","গোটা","চলে","চান","চায়","চার","চালু","চেয়ে","চেষ্টা","ছাড়া","ছাড়াও","ছিল","ছিলেন","জন","জনকে","জনের","জন্য","জন্যওজে","জানতে","জানা","জানানো","জানায়","জানিয়ে","জানিয়েছে","জে","জ্নজন","টি","ঠিক","তখন","তত","তথা","তবু","তবে","তা","তাঁকে","তাঁদের","তাঁর","তাঁরা","তাঁাহারা","তাই","তাও","তাকে","তাতে","তাদের","তার","তারপর","তারা","তারৈ","তাহলে","তাহা","তাহাতে","তাহার","তিনঐ","তিনি","তিনিও","তুমি","তুলে","তেমন","তো","তোমার","থাকবে","থাকবেন","থাকা","থাকায়","থাকে","থাকেন","থেকে","থেকেই","থেকেও","দিকে","দিতে","দিন","দিয়ে","দিয়েছে","দিয়েছেন","দিলেন","দু","দুই","দুটি","দুটো","দেওয়া","দেওয়ার","দেওয়া","দেখতে","দেখা","দেখে","দেন","দেয়","দ্বারা","ধরা","ধরে","ধামার","নতুন","নাকি","নাগাদ","নানা","নিজে","নিজেই","নিজেদের","নিজের","নিতে","নিয়ে","নিয়ে","নেওয়া","নেওয়ার","নেওয়া","নয়","পক্ষে","পর","পরে","পরেই","পরেও","পর্যন্ত","পাওয়া","পাচ","পারি","পারে","পারেন","পি","পেয়ে","পেয়্র্","প্রতি","প্রথম","প্রভৃতি","প্রযন্ত","প্রাথমিক","প্রায়","প্রায়","ফলে","ফিরে","ফের","বক্তব্য","বদলে","বন","বরং","বলতে","বলল","বললেন","বলা","বলে","বলেছেন","বলেন","বসে","বহু","বা","বাদে","বার","বি","বিনা","বিভিন্ন","বিশেষ","বিষয়টি","বেশ","বেশি","ব্যবহার","ব্যাপারে","ভাবে","ভাবেই","মতো","মতোই","মধ্যভাগে","মধ্যে","মধ্যেই","মধ্যেও","মনে","মাত্র","মাধ্যমে","মোট","মোটেই","যখন","যত","যতটা","যথেষ্ট","যদি","যদিও","যা","যাঁর","যাঁরা","যাওয়া","যাওয়ার","যাওয়া","যাকে","যাচ্ছে","যাতে","যাদের","যান","যাবে","যায়","যার","যারা","যিনি","যে","যেখানে","যেতে","যেন","যেমন","র","রকম","রয়েছে","রাখা","রেখে","লক্ষ","শুধু","শুরু","সঙ্গে","সঙ্গেও","সব","সবার","সমস্ত","সম্প্রতি","সহ","সহিত","সাধারণ","সামনে","সি","সুতরাং","সে","সেই","সেখান","সেখানে","সেটা","সেটাই","সেটাও","সেটি","স্পষ্ট","স্বয়ং","হইতে","হইবে","হইয়া","হওয়া","হওয়ায়","হওয়ার","হচ্ছে","হত","হতে","হতেই","হন","হবে","হবেন","হয়","হয়তো","হয়নি","হয়ে","হয়েই","হয়েছিল","হয়েছে","হয়েছেন","হল","হলে","হলেই","হলেও","হলো","হাজার","হিসাবে","হৈলে","হোক","হয়"]
    lines = [re.sub(r'[^\u0980-\u09FF]+',' ',sentence) for sentence in data]
    lines = [re.sub(r'[\u09E6-\u09EF]+','',sentence) for sentence in data]
    lines = [re.sub(r'[0-9a-zA-Z]+','',sentence) for sentence in data]
    for text in lines: 
        pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
        text = pattern.sub('', text)
        
        emoji = re.compile("["
                           u"\U0001F600-\U0001FFFF"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
        text = emoji.sub(r'', text)
        
        text = re.sub(r"[।“,”'’‘.\"!@#$%^&*(){}?/;`~:<>+=-]", "", text)
        text = re.sub(r"\s+$", "", text)
        text = re.sub(r"^\s", "", text)
        tokens = word_tokenize(text)
        words = [w for w in tokens if not w in stopwords_bn]
        all_data.append(words) 
    
#     removing numbers and empty words
    for line in all_data:
            line = [re.sub(r'[\u09E6-\u09EF]+','',word) for word in line]
            line = [w for w in line if not w == '']
            final_data.append(line)
    
    return final_data

# %%
cleaned_data = clean_text(posts)

# %%
features = 200
tokenizer = Tokenizer(num_words=features)

# %%
tokenizer.fit_on_texts(cleaned_data)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(cleaned_data)

maxlen=15
padType='post'

X = pad_sequences(sequences, maxlen=maxlen, padding="post", truncating="post")
y = np.asarray(pd.get_dummies(labels))

# %%
len(X), len(y)
# Out:
# (1402, 1402)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle = True)

# %%
word_model = gensim.models.Word2Vec(cleaned_data, vector_size=features, min_count=1, window=3, epochs=50, sg=1)

# %%
print(len(word_model.wv.key_to_index))
# print (X.shape)
# print (y.shape)

print(word_model.wv.most_similar('মৃত্যু'))
# print(word_model.wv['মৃত্যু'])
# print(word_model.wv.key_to_index)
# print(word_index)
# Out:
# 3806
# [('স্মরণ', 0.9644662737846375), ('প্রতিদিনের', 0.9609816074371338), ('বড়', 0.9606979489326477), ('এটির', 0.9604619145393372), ('সবকিছুর', 0.9594612121582031), ('বেশিরভাগ', 0.9594449400901794), ('বছরেরও', 0.9590425491333008), ('মেয়ে', 0.9581306576728821), ('চারপাশের', 0.9579930305480957), ('সম্পাদন', 0.9576002359390259)]

# %%
embedding_matrix = np.zeros((len(word_index) + 1, features))
c = 0
for word, i in word_index.items():
    embedding_vector = word_model.wv[word]
    if embedding_vector is not None:
        c+=1
        embedding_matrix[i] = embedding_vector
print(c)
# Out:
# 3806

# %%
# There are three parameters to the embedding layer
# input_dim : Size of the vocabulary
# output_dim : Length of the vector for each word
# input_length : Maximum length of a sequence

# %%
def get_model(num_of_layer):
    model = Sequential()
    model.add(Embedding(input_dim=len(word_model.wv.key_to_index)+1, output_dim=features, weights=[embedding_matrix], input_length=X.shape[1], trainable=False))

    model.add(Conv1D(filters=features, kernel_size=2, activation='relu'))
#     model.add(Dropout(0.5))

    for i in range(num_of_layer):
        if i>0:
            model.add(LSTM(features, return_sequences=True))
            
    model.add(LSTM(features, return_sequences=False))
    model.add(Dense(10, activation="relu"))
    model.add(Dense(y.shape[1], activation="softmax"))

    opt = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    # model.summary()
    return model

# %%
def run_model(model, batch, epochs):
    history = model.fit(X_train, y_train, batch, epochs, validation_data=(X_test, y_test), verbose=1)
    return history

# %%
#plot

import matplotlib.pyplot as plt

def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# %%
arr_batch = [32]
arr_epochs = [10,20,30]
algo_layers = [1,3,5]
output = {}
idx = 0
for batch in arr_batch:
    for epoch in arr_epochs:
        for layer in algo_layers:
            model = get_model(layer)
            history = run_model(model, batch, epoch)
            ev = model.evaluate(X_test, y_test)
            
            plot_graphs(history, "accuracy")
            plot_graphs(history, "loss")

            y_pred=model.predict(X_test) 
            y_pred=np.argmax(y_pred, axis=1)
            formated_y_test=np.argmax(y_test, axis=1)
            cm = classification_report(formated_y_test, y_pred)
            print(cm)
            
            output[idx] = {'batch':batch, 'epoch':epoch, 'num_of_layer':layer, 'acc':ev, 'cm':cm}
            idx = idx+1;
# Out:
# Epoch 1/10
# 36/36 [==============================] - 6s 75ms/step - loss: 0.6803 - accuracy: 0.7092 - val_loss: 0.6431 - val_accuracy: 0.7900
# Epoch 2/10
# 36/36 [==============================] - 2s 49ms/step - loss: 0.4979 - accuracy: 0.8403 - val_loss: 0.2988 - val_accuracy: 0.8897
# Epoch 3/10
# 36/36 [==============================] - 2s 45ms/step - loss: 0.2670 - accuracy: 0.9081 - val_loss: 0.3083 - val_accuracy: 0.8754
# Epoch 4/10
# 36/36 [==============================] - 2s 46ms/step - loss: 0.2500 - accuracy: 0.9063 - val_loss: 0.2796 - val_accuracy: 0.8826
# Epoch 5/10
# 36/36 [==============================] - 2s 51ms/step - loss: 0.2284 - accuracy: 0.9215 - val_loss: 0.3034 - val_accuracy: 0.8861
# Epoch 6/10
# 36/36 [==============================] - 2s 47ms/step - loss: 0.2231 - accuracy: 0.9206 - val_loss: 0.2872 - val_accuracy: 0.8861
# Epoch 7/10
# 36/36 [==============================] - 2s 42ms/step - loss: 0.2190 - accuracy: 0.9215 - val_loss: 0.2755 - val_accuracy: 0.8897
# Epoch 8/10
# 36/36 [==============================] - 2s 45ms/step - loss: 0.2141 - accuracy: 0.9215 - val_loss: 0.2973 - val_accuracy: 0.8826
# Epoch 9/10
# 36/36 [==============================] - 2s 46ms/step - loss: 0.2123 - accuracy: 0.9251 - val_loss: 0.2987 - val_accuracy: 0.8826
# Epoch 10/10
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2072 - accuracy: 0.9277 - val_loss: 0.2719 - val_accuracy: 0.8826
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2719 - accuracy: 0.8826
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89       143
#            1       0.91      0.85      0.88       138
#
#     accuracy                           0.88       281
#    macro avg       0.88      0.88      0.88       281
# weighted avg       0.88      0.88      0.88       281
#
# Epoch 1/10
# 36/36 [==============================] - 13s 169ms/step - loss: 0.6386 - accuracy: 0.6021 - val_loss: 0.5311 - val_accuracy: 0.7473
# Epoch 2/10
# 36/36 [==============================] - 4s 116ms/step - loss: 0.3639 - accuracy: 0.8787 - val_loss: 0.2807 - val_accuracy: 0.8826
# Epoch 3/10
# 36/36 [==============================] - 4s 117ms/step - loss: 0.2420 - accuracy: 0.9090 - val_loss: 0.2965 - val_accuracy: 0.8826
# Epoch 4/10
# 36/36 [==============================] - 4s 118ms/step - loss: 0.2281 - accuracy: 0.9161 - val_loss: 0.2951 - val_accuracy: 0.8790
# Epoch 5/10
# 36/36 [==============================] - 4s 111ms/step - loss: 0.2189 - accuracy: 0.9206 - val_loss: 0.2763 - val_accuracy: 0.8861
# Epoch 6/10
# 36/36 [==============================] - 4s 107ms/step - loss: 0.2199 - accuracy: 0.9215 - val_loss: 0.2738 - val_accuracy: 0.8897
# Epoch 7/10
# 36/36 [==============================] - 4s 109ms/step - loss: 0.2099 - accuracy: 0.9233 - val_loss: 0.2680 - val_accuracy: 0.8897
# Epoch 8/10
# 36/36 [==============================] - 4s 107ms/step - loss: 0.2069 - accuracy: 0.9215 - val_loss: 0.2738 - val_accuracy: 0.8897
# Epoch 9/10
# 36/36 [==============================] - 4s 119ms/step - loss: 0.2007 - accuracy: 0.9233 - val_loss: 0.2778 - val_accuracy: 0.8861
# Epoch 10/10
# 36/36 [==============================] - 5s 132ms/step - loss: 0.1999 - accuracy: 0.9277 - val_loss: 0.2984 - val_accuracy: 0.8861
# 9/9 [==============================] - 1s 71ms/step - loss: 0.2984 - accuracy: 0.8861
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       143
#            1       0.89      0.88      0.88       138
#
#     accuracy                           0.89       281
#    macro avg       0.89      0.89      0.89       281
# weighted avg       0.89      0.89      0.89       281
#
# Epoch 1/10
# 36/36 [==============================] - 24s 288ms/step - loss: 0.6118 - accuracy: 0.6896 - val_loss: 0.4397 - val_accuracy: 0.8577
# Epoch 2/10
# 36/36 [==============================] - 7s 187ms/step - loss: 0.2722 - accuracy: 0.9045 - val_loss: 0.3457 - val_accuracy: 0.8861
# Epoch 3/10
# 36/36 [==============================] - 7s 193ms/step - loss: 0.2300 - accuracy: 0.9170 - val_loss: 0.2736 - val_accuracy: 0.8826
# Epoch 4/10
# 36/36 [==============================] - 8s 238ms/step - loss: 0.2334 - accuracy: 0.9126 - val_loss: 0.2717 - val_accuracy: 0.8826
# Epoch 5/10
# 36/36 [==============================] - 8s 212ms/step - loss: 0.2155 - accuracy: 0.9206 - val_loss: 0.2738 - val_accuracy: 0.8861
# Epoch 6/10
# 36/36 [==============================] - 7s 208ms/step - loss: 0.2093 - accuracy: 0.9215 - val_loss: 0.2826 - val_accuracy: 0.8861
# Epoch 7/10
# 36/36 [==============================] - 8s 226ms/step - loss: 0.2106 - accuracy: 0.9215 - val_loss: 0.2675 - val_accuracy: 0.8897
# Epoch 8/10
# 36/36 [==============================] - 8s 216ms/step - loss: 0.2013 - accuracy: 0.9233 - val_loss: 0.2699 - val_accuracy: 0.8790
# Epoch 9/10
# 36/36 [==============================] - 8s 230ms/step - loss: 0.1994 - accuracy: 0.9233 - val_loss: 0.2728 - val_accuracy: 0.8897
# Epoch 10/10
# 36/36 [==============================] - 8s 228ms/step - loss: 0.1949 - accuracy: 0.9251 - val_loss: 0.2718 - val_accuracy: 0.8897
# 9/9 [==============================] - 1s 67ms/step - loss: 0.2718 - accuracy: 0.8897
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89       143
#            1       0.91      0.86      0.88       138
#
#     accuracy                           0.89       281
#    macro avg       0.89      0.89      0.89       281
# weighted avg       0.89      0.89      0.89       281
#
# Epoch 1/20
# 36/36 [==============================] - 6s 72ms/step - loss: 0.6818 - accuracy: 0.5120 - val_loss: 0.6454 - val_accuracy: 0.6904
# Epoch 2/20
# 36/36 [==============================] - 2s 48ms/step - loss: 0.5447 - accuracy: 0.7886 - val_loss: 0.4602 - val_accuracy: 0.8577
# Epoch 3/20
# 36/36 [==============================] - 2s 47ms/step - loss: 0.3692 - accuracy: 0.8938 - val_loss: 0.3313 - val_accuracy: 0.8719
# Epoch 4/20
# 36/36 [==============================] - 2s 48ms/step - loss: 0.2623 - accuracy: 0.9090 - val_loss: 0.2835 - val_accuracy: 0.8790
# Epoch 5/20
# 36/36 [==============================] - 2s 48ms/step - loss: 0.2353 - accuracy: 0.9153 - val_loss: 0.2813 - val_accuracy: 0.8826
# Epoch 6/20
# 36/36 [==============================] - 2s 50ms/step - loss: 0.2191 - accuracy: 0.9170 - val_loss: 0.3287 - val_accuracy: 0.8861
# Epoch 7/20
# 36/36 [==============================] - 2s 47ms/step - loss: 0.2246 - accuracy: 0.9179 - val_loss: 0.2881 - val_accuracy: 0.8861
# Epoch 8/20
# 36/36 [==============================] - 2s 49ms/step - loss: 0.2159 - accuracy: 0.9215 - val_loss: 0.2754 - val_accuracy: 0.8826
# Epoch 9/20
# 36/36 [==============================] - 2s 47ms/step - loss: 0.2091 - accuracy: 0.9242 - val_loss: 0.2790 - val_accuracy: 0.8861
# Epoch 10/20
# 36/36 [==============================] - 2s 47ms/step - loss: 0.2043 - accuracy: 0.9233 - val_loss: 0.2866 - val_accuracy: 0.8861
# Epoch 11/20
# 36/36 [==============================] - 2s 48ms/step - loss: 0.2021 - accuracy: 0.9251 - val_loss: 0.3005 - val_accuracy: 0.8897
# Epoch 12/20
# 36/36 [==============================] - 2s 46ms/step - loss: 0.1973 - accuracy: 0.9269 - val_loss: 0.2821 - val_accuracy: 0.8861
# Epoch 13/20
# 36/36 [==============================] - 2s 48ms/step - loss: 0.1953 - accuracy: 0.9269 - val_loss: 0.2889 - val_accuracy: 0.8861
# Epoch 14/20
# 36/36 [==============================] - 2s 49ms/step - loss: 0.1976 - accuracy: 0.9269 - val_loss: 0.2849 - val_accuracy: 0.8826
# Epoch 15/20
# 36/36 [==============================] - 2s 48ms/step - loss: 0.1911 - accuracy: 0.9286 - val_loss: 0.2843 - val_accuracy: 0.8826
# Epoch 16/20
# 36/36 [==============================] - 2s 47ms/step - loss: 0.1864 - accuracy: 0.9331 - val_loss: 0.2952 - val_accuracy: 0.8826
# Epoch 17/20
# 36/36 [==============================] - 2s 48ms/step - loss: 0.1873 - accuracy: 0.9331 - val_loss: 0.2883 - val_accuracy: 0.8897
# Epoch 18/20
# 36/36 [==============================] - 2s 49ms/step - loss: 0.1856 - accuracy: 0.9340 - val_loss: 0.2983 - val_accuracy: 0.8897
# Epoch 19/20
# 36/36 [==============================] - 2s 48ms/step - loss: 0.1820 - accuracy: 0.9340 - val_loss: 0.3118 - val_accuracy: 0.8897
# Epoch 20/20
# 36/36 [==============================] - 2s 50ms/step - loss: 0.1782 - accuracy: 0.9340 - val_loss: 0.3198 - val_accuracy: 0.8826
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3198 - accuracy: 0.8826
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89       143
#            1       0.89      0.86      0.88       138
#
#     accuracy                           0.88       281
#    macro avg       0.88      0.88      0.88       281
# weighted avg       0.88      0.88      0.88       281
#
# Epoch 1/20
# 36/36 [==============================] - 20s 239ms/step - loss: 0.6280 - accuracy: 0.6780 - val_loss: 0.4612 - val_accuracy: 0.8541
# Epoch 2/20
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90       143
#            1       0.92      0.87      0.90       138
#
#     accuracy                           0.90       281
#    macro avg       0.90      0.90      0.90       281
# weighted avg       0.90      0.90      0.90       281
#
# Epoch 1/30
# 36/36 [==============================] - 8s 101ms/step - loss: 0.6830 - accuracy: 0.6075 - val_loss: 0.6567 - val_accuracy: 0.6762
# Epoch 2/30
# 36/36 [==============================] - 3s 78ms/step - loss: 0.5622 - accuracy: 0.7921 - val_loss: 0.4513 - val_accuracy: 0.8790
# Epoch 3/30
# 36/36 [==============================] - 3s 77ms/step - loss: 0.3551 - accuracy: 0.9135 - val_loss: 0.3064 - val_accuracy: 0.8754
# Epoch 4/30
# 36/36 [==============================] - 3s 75ms/step - loss: 0.2484 - accuracy: 0.9161 - val_loss: 0.2984 - val_accuracy: 0.8790
# Epoch 5/30
# 36/36 [==============================] - 3s 78ms/step - loss: 0.2303 - accuracy: 0.9179 - val_loss: 0.2855 - val_accuracy: 0.8754
# Epoch 6/30
# 36/36 [==============================] - 3s 75ms/step - loss: 0.2272 - accuracy: 0.9188 - val_loss: 0.2794 - val_accuracy: 0.8861
# Epoch 7/30
# 36/36 [==============================] - 3s 83ms/step - loss: 0.2157 - accuracy: 0.9206 - val_loss: 0.2958 - val_accuracy: 0.8790
# Epoch 8/30
# 36/36 [==============================] - 2s 63ms/step - loss: 0.2118 - accuracy: 0.9206 - val_loss: 0.2852 - val_accuracy: 0.8861s - loss: 0.2115
# Epoch 9/30
# 36/36 [==============================] - 2s 58ms/step - loss: 0.2106 - accuracy: 0.9260 - val_loss: 0.3301 - val_accuracy: 0.8719
# Epoch 10/30
# 36/36 [==============================] - 2s 62ms/step - loss: 0.2126 - accuracy: 0.9215 - val_loss: 0.2905 - val_accuracy: 0.8790
# Epoch 11/30
# 36/36 [==============================] - 2s 69ms/step - loss: 0.2062 - accuracy: 0.9269 - val_loss: 0.2931 - val_accuracy: 0.8790
# Epoch 12/30
# 36/36 [==============================] - 3s 78ms/step - loss: 0.2017 - accuracy: 0.9286 - val_loss: 0.2922 - val_accuracy: 0.8826
# Epoch 13/30
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1975 - accuracy: 0.9304 - val_loss: 0.2876 - val_accuracy: 0.8826
# Epoch 14/30
# 36/36 [==============================] - 3s 77ms/step - loss: 0.2181 - accuracy: 0.9215 - val_loss: 0.3129 - val_accuracy: 0.8719
# Epoch 15/30
# 36/36 [==============================] - 3s 83ms/step - loss: 0.1966 - accuracy: 0.9313 - val_loss: 0.2930 - val_accuracy: 0.8826
# Epoch 16/30
# 36/36 [==============================] - 3s 81ms/step - loss: 0.1914 - accuracy: 0.9313 - val_loss: 0.2968 - val_accuracy: 0.8826
# Epoch 17/30
# 36/36 [==============================] - 3s 90ms/step - loss: 0.1896 - accuracy: 0.9322 - val_loss: 0.2931 - val_accuracy: 0.8826
# Epoch 18/30
# 36/36 [==============================] - 3s 94ms/step - loss: 0.1877 - accuracy: 0.9349 - val_loss: 0.3098 - val_accuracy: 0.8826
# Epoch 19/30
# 36/36 [==============================] - 4s 100ms/step - loss: 0.1873 - accuracy: 0.9340 - val_loss: 0.3033 - val_accuracy: 0.8826
# Epoch 20/30
# 36/36 [==============================] - 3s 83ms/step - loss: 0.1842 - accuracy: 0.9340 - val_loss: 0.3037 - val_accuracy: 0.8826
# Epoch 21/30
# 36/36 [==============================] - 3s 88ms/step - loss: 0.1808 - accuracy: 0.9349 - val_loss: 0.2906 - val_accuracy: 0.8897
# Epoch 22/30
# 36/36 [==============================] - 2s 66ms/step - loss: 0.1885 - accuracy: 0.9322 - val_loss: 0.2805 - val_accuracy: 0.8897
# Epoch 23/30
# 36/36 [==============================] - 4s 101ms/step - loss: 0.1801 - accuracy: 0.9349 - val_loss: 0.2963 - val_accuracy: 0.8861
# Epoch 24/30
# 36/36 [==============================] - 4s 98ms/step - loss: 0.1753 - accuracy: 0.9367 - val_loss: 0.3041 - val_accuracy: 0.8861
# Epoch 25/30
# 36/36 [==============================] - 3s 78ms/step - loss: 0
# Epoch 4/30
# 36/36 [==============================] - 8s 233ms/step - loss: 0.2340 - accuracy: 0.9126 - val_loss: 0.2973 - val_accuracy: 0.8754
# Epoch 5/30
# 36/36 [==============================] - 8s 223ms/step - loss: 0.2241 - accuracy: 0.9135 - val_loss: 0.2962 - val_accuracy: 0.8826
# Epoch 6/30
# 36/36 [==============================] - 8s 229ms/step - loss: 0.2293 - accuracy: 0.9054 - val_loss: 0.2913 - val_accuracy: 0.8897
# Epoch 7/30
# 36/36 [==============================] - 9s 261ms/step - loss: 0.2199 - accuracy: 0.9126 - val_loss: 0.2934 - val_accuracy: 0.8826
# Epoch 8/30
# 36/36 [==============================] - 10s 269ms/step - loss: 0.2101 - accuracy: 0.9206 - val_loss: 0.2712 - val_accuracy: 0.8790
# Epoch 9/30
# 36/36 [==============================] - 10s 290ms/step - loss: 0.2093 - accuracy: 0.9206 - val_loss: 0.2710 - val_accuracy: 0.8861
# Epoch 10/30
# 36/36 [==============================] - 14s 376ms/step - loss: 0.2319 - accuracy: 0.9117 - val_loss: 0.2650 - val_accuracy: 0.8826
# Epoch 11/30
# 36/36 [==============================] - 12s 330ms/step - loss: 0.1987 - accuracy: 0.9260 - val_loss: 0.3073 - val_accuracy: 0.8826
# Epoch 12/30
# 36/36 [==============================] - 12s 320ms/step - loss: 0.2001 - accuracy: 0.9251 - val_loss: 0.2711 - val_accuracy: 0.8826
# Epoch 13/30
# 36/36 [==============================] - 12s 322ms/step - loss: 0.1942 - accuracy: 0.9269 - val_loss: 0.2961 - val_accuracy: 0.8826
# Epoch 14/30
# 36/36 [==============================] - 11s 307ms/step - loss: 0.1940 - accuracy: 0.9286 - val_loss: 0.2720 - val_accuracy: 0.8897
# Epoch 15/30
# 36/36 [==============================] - 12s 325ms/step - loss: 0.2115 - accuracy: 0.9170 - val_loss: 0.2982 - val_accuracy: 0.8719
# Epoch 16/30
# 36/36 [==============================] - 11s 309ms/step - loss: 0.1940 - accuracy: 0.9251 - val_loss: 0.2849 - val_accuracy: 0.8861
# Epoch 17/30
# 36/36 [==============================] - 11s 318ms/step - loss: 0.1879 - accuracy: 0.9286 - val_loss: 0.2730 - val_accuracy: 0.8897
# Epoch 18/30
# 36/36 [==============================] - 11s 298ms/step - loss: 0.1812 - accuracy: 0.9313 - val_loss: 0.3013 - val_accuracy: 0.8861
# Epoch 19/30
# 36/36 [==============================] - 10s 280ms/step - loss: 0.1817 - accuracy: 0.9340 - val_loss: 0.2876 - val_accuracy: 0.8932
# Epoch 20/30
# 36/36 [==============================] - 11s 307ms/step - loss: 0.1796 - accuracy: 0.9295 - val_loss: 0.3173 - val_accuracy: 0.8790
# Epoch 21/30
# 36/36 [==============================] - 11s 306ms/step - loss: 0.1891 - accuracy: 0.9277 - val_loss: 0.2908 - val_accuracy: 0.8968
# Epoch 22/30
# 36/36 [==============================] - 11s 298ms/step - loss: 0.1761 - accuracy: 0.9340 - val_loss: 0.2890 - val_accuracy: 0.8932
# Epoch 23/30
# 36/36 [==============================] - 12s 328ms/step - loss: 0.1719 - accuracy: 0.9367 - val_loss: 0.2785 - val_accuracy: 0.8897
# Epoch 24/30
# 36/36 [==============================] - 11s 315ms/step - loss: 0.1668 - accuracy: 0.9376 - val_loss: 0.2890 - val_accuracy: 0.8968
# Epoch 25/30
# 36/36 [==============================] - 11s 305ms/step - loss: 0.1659 - accuracy: 0.9367 - val_loss: 0.3010 - val_accuracy: 0.9004
# Epoch 26/30
# 36/36 [==============================] - 11s 306ms/step - loss: 0.1610 - accuracy: 0.9384 - val_loss: 0.3071 - val_accuracy: 0.8932
# Epoch 27/30
# 36/36 [==============================] - 11s 298ms/step - loss: 0.1579 - accuracy: 0.9367 - val_loss: 0.2845 - val_accuracy: 0.8897
# Epoch 28/30
# 36/36 [==============================] - 10s 281ms/step - loss: 0.1552 - accuracy: 0.9393 - val_loss: 0.3198 - val_accuracy: 0.8968
# Epoch 29/30
# 36/36 [==============================] - 11s 303ms/step - loss: 0.1532 - accuracy: 0.9384 - val_loss: 0.3096 - val_accuracy: 0.8897
# Epoch 30/30
# 36/36 [==============================] - 11s 305ms/step - loss: 0.1488 - accuracy: 0.9420 - val_loss: 0.3290 - val_accuracy: 0.8932
# 9/9 [==============================] - 1s 110ms/step - loss: 0.3290 - accuracy: 0.8932
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       143
#            1       0.92      0.86      0.89       138
#
#     accuracy                           0.89       281
#    macro avg       0.90      0.89      0.89       281
# weighted avg       0.90      0.89      0.89       281

# %%
output
# Out:
# {0: {'batch': 32,
#   'epoch': 10,
#   'num_of_layer': 1,
#   'acc': [0.27187782526016235, 0.8825622797012329],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.86      0.92      0.89       143\n           1       0.91      0.85      0.88       138\n\n    accuracy                           0.88       281\n   macro avg       0.88      0.88      0.88       281\nweighted avg       0.88      0.88      0.88       281\n'},
#  1: {'batch': 32,
#   'epoch': 10,
#   'num_of_layer': 3,
#   'acc': [0.29841867089271545, 0.8861209750175476],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.88      0.90      0.89       143\n           1       0.89      0.88      0.88       138\n\n    accuracy                           0.89       281\n   macro avg       0.89      0.89      0.89       281\nweighted avg       0.89      0.89      0.89       281\n'},
#  2: {'batch': 32,
#   'epoch': 10,
#   'num_of_layer': 5,
#   'acc': [0.2718403935432434, 0.8896797299385071],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.87      0.92      0.89       143\n           1       0.91      0.86      0.88       138\n\n    accuracy                           0.89       281\n   macro avg       0.89      0.89      0.89       281\nweighted avg       0.89      0.89      0.89       281\n'},
#  3: {'batch': 32,
#   'epoch': 20,
#   'num_of_layer': 1,
#   'acc': [0.31981176137924194, 0.8825622797012329],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.87      0.90      0.89       143\n           1       0.89      0.86      0.88       138\n\n    accuracy                           0.88       281\n   macro avg       0.88      0.88      0.88       281\nweighted avg       0.88      0.88      0.88       281\n'},
#  4: {'batch': 32,
#   'epoch': 20,
#   'num_of_layer': 3,
#   'acc': [0.3027985095977783, 0.8896797299385071],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.88      0.90      0.89       143\n           1       0.90      0.88      0.89       138\n\n    accuracy                           0.89       281\n   macro avg       0.89      0.89      0.89       281\nweighted avg       0.89      0.89      0.89       281\n'},
#  5: {'batch': 32,
#   'epoch': 20,
#   'num_of_layer': 5,
#   'acc': [0.2795960605144501, 0.900355875492096],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.88      0.93      0.90       143\n           1       0.92      0.87      0.90       138\n\n    accuracy                           0.90       281\n   macro avg       0.90      0.90      0.90       281\nweighted avg       0.90      0.90      0.90       281\n'},
#  6: {'batch': 32,
#   'epoch': 30,
#   'num_of_layer': 1,
#   'acc': [0.31911027431488037, 0.8896797299385071],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.88      0.91      0.89       143\n           1       0.90      0.87      0.89       138\n\n    accuracy                           0.89       281\n   macro avg       0.89      0.89      0.89       281\nweighted avg       0.89      0.89      0.89       281\n'},
#  7: {'batch': 32,
#   'epoch': 30,
#   'num_of_layer': 3,
#   'acc': [0.3136802613735199, 0.8896797299385071],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.88      0.91      0.89       143\n           1       0.90      0.87      0.89       138\n\n    accuracy                           0.89       281\n   macro avg       0.89      0.89      0.89       281\nweighted avg       0.89      0.89      0.89       281\n'},
#  8: {'batch': 32,
#   'epoch': 30,
#   'num_of_layer': 5,
#   'acc': [0.3290134072303772, 0.8932384252548218],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.87      0.93      0.90       143\n           1       0.92      0.86      0.89       138\n\n    accuracy                           0.89       281\n   macro avg       0.90      0.89      0.89       281\nweighted avg       0.90      0.89      0.89       281\n'}}

# %%
import json
json_object = json.dumps(output, indent = 4)
with open('model_v0.0.0_sg_cnn_lstm_dense.json', 'a') as fp:
    fp.write(json_object)
