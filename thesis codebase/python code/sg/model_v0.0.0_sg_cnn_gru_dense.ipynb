# %%
import tensorflow as tf
keras = tf.keras
import warnings
warnings.filterwarnings("ignore")
import gensim, re
import numpy as np
import pandas as pd
import openpyxl
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences 
from tensorflow.keras.models import load_model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Embedding, Bidirectional, Dropout, Conv1D

# %%
main_data = pd.read_excel( r"C:\Users\Dhrubo\1_Thesis\data_v2\suicide_data.xlsx", sheet_name="Sheet1" )
print(main_data.columns.ravel())
posts = main_data['text'].tolist()
labels = main_data['label'].tolist()
# Out:
# ['text' 'label']

# %%
from nltk.tokenize import word_tokenize

def clean_text(data):
    all_data = list()
    final_data = list()
    stopwords_bn = ["অতএব","অথচ","অথবা","অনুযায়ী","অনেক","অনেকে","অনেকেই","অন্তত","অন্য","অবধি","অবশ্য","অর্থাত","আই","আগামী","আগে","আগেই","আছে","আজ","আদ্যভাগে","আপনার","আপনি","আবার","আমরা","আমাকে","আমাদের","আমার","আমি","আর","আরও","ই","ইত্যাদি","ইহা","উচিত","উত্তর","উনি","উপর","উপরে","এ","এঁদের","এঁরা","এই","একই","একটি","একবার","একে","এক্","এখন","এখনও","এখানে","এখানেই","এটা","এটাই","এটি","এত","এতটাই","এতে","এদের","এব","এবং","এবার","এমন","এমনকী","এমনি","এর","এরা","এল","এস","এসে","ঐ","ও","ওঁদের","ওঁর","ওঁরা","ওই","ওকে","ওখানে","ওদের","ওর","ওরা","কখনও","কত","কবে","কমনে","কয়েক","কয়েকটি","করছে","করছেন","করতে","করবে","করবেন","করলে","করলেন","করা","করাই","করায়","করার","করি","করিতে","করিয়া","করিয়ে","করে","করেই","করেছিলেন","করেছে","করেছেন","করেন","কাউকে","কাছ","কাছে","কাজ","কাজে","কারও","কারণ","কি","কিংবা","কিছু","কিছুই","কিন্তু","কী","কে","কেউ","কেউই","কেখা","কেন","কোটি","কোন","কোনও","কোনো","ক্ষেত্রে","কয়েক","খুব","গিয়ে","গিয়েছে","গিয়ে","গুলি","গেছে","গেল","গেলে","গোটা","চলে","চান","চায়","চার","চালু","চেয়ে","চেষ্টা","ছাড়া","ছাড়াও","ছিল","ছিলেন","জন","জনকে","জনের","জন্য","জন্যওজে","জানতে","জানা","জানানো","জানায়","জানিয়ে","জানিয়েছে","জে","জ্নজন","টি","ঠিক","তখন","তত","তথা","তবু","তবে","তা","তাঁকে","তাঁদের","তাঁর","তাঁরা","তাঁাহারা","তাই","তাও","তাকে","তাতে","তাদের","তার","তারপর","তারা","তারৈ","তাহলে","তাহা","তাহাতে","তাহার","তিনঐ","তিনি","তিনিও","তুমি","তুলে","তেমন","তো","তোমার","থাকবে","থাকবেন","থাকা","থাকায়","থাকে","থাকেন","থেকে","থেকেই","থেকেও","দিকে","দিতে","দিন","দিয়ে","দিয়েছে","দিয়েছেন","দিলেন","দু","দুই","দুটি","দুটো","দেওয়া","দেওয়ার","দেওয়া","দেখতে","দেখা","দেখে","দেন","দেয়","দ্বারা","ধরা","ধরে","ধামার","নতুন","নাকি","নাগাদ","নানা","নিজে","নিজেই","নিজেদের","নিজের","নিতে","নিয়ে","নিয়ে","নেওয়া","নেওয়ার","নেওয়া","নয়","পক্ষে","পর","পরে","পরেই","পরেও","পর্যন্ত","পাওয়া","পাচ","পারি","পারে","পারেন","পি","পেয়ে","পেয়্র্","প্রতি","প্রথম","প্রভৃতি","প্রযন্ত","প্রাথমিক","প্রায়","প্রায়","ফলে","ফিরে","ফের","বক্তব্য","বদলে","বন","বরং","বলতে","বলল","বললেন","বলা","বলে","বলেছেন","বলেন","বসে","বহু","বা","বাদে","বার","বি","বিনা","বিভিন্ন","বিশেষ","বিষয়টি","বেশ","বেশি","ব্যবহার","ব্যাপারে","ভাবে","ভাবেই","মতো","মতোই","মধ্যভাগে","মধ্যে","মধ্যেই","মধ্যেও","মনে","মাত্র","মাধ্যমে","মোট","মোটেই","যখন","যত","যতটা","যথেষ্ট","যদি","যদিও","যা","যাঁর","যাঁরা","যাওয়া","যাওয়ার","যাওয়া","যাকে","যাচ্ছে","যাতে","যাদের","যান","যাবে","যায়","যার","যারা","যিনি","যে","যেখানে","যেতে","যেন","যেমন","র","রকম","রয়েছে","রাখা","রেখে","লক্ষ","শুধু","শুরু","সঙ্গে","সঙ্গেও","সব","সবার","সমস্ত","সম্প্রতি","সহ","সহিত","সাধারণ","সামনে","সি","সুতরাং","সে","সেই","সেখান","সেখানে","সেটা","সেটাই","সেটাও","সেটি","স্পষ্ট","স্বয়ং","হইতে","হইবে","হইয়া","হওয়া","হওয়ায়","হওয়ার","হচ্ছে","হত","হতে","হতেই","হন","হবে","হবেন","হয়","হয়তো","হয়নি","হয়ে","হয়েই","হয়েছিল","হয়েছে","হয়েছেন","হল","হলে","হলেই","হলেও","হলো","হাজার","হিসাবে","হৈলে","হোক","হয়"]
    lines = [re.sub(r'[^\u0980-\u09FF]+',' ',sentence) for sentence in data]
    lines = [re.sub(r'[\u09E6-\u09EF]+','',sentence) for sentence in data]
    lines = [re.sub(r'[0-9a-zA-Z]+','',sentence) for sentence in data]
    for text in lines: 
        pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
        text = pattern.sub('', text)
        
        emoji = re.compile("["
                           u"\U0001F600-\U0001FFFF"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
        text = emoji.sub(r'', text)
        
        text = re.sub(r"[।“,”'’‘.\"!@#$%^&*(){}?/;`~:<>+=-]", "", text)
        text = re.sub(r"\s+$", "", text)
        text = re.sub(r"^\s", "", text)
        tokens = word_tokenize(text)
        words = [w for w in tokens if not w in stopwords_bn]
        all_data.append(words) 
    
#     removing numbers and empty words
    for line in all_data:
            line = [re.sub(r'[\u09E6-\u09EF]+','',word) for word in line]
            line = [w for w in line if not w == '']
            final_data.append(line)
    
    return final_data

# %%
cleaned_data = clean_text(posts)

# %%
features = 200
tokenizer = Tokenizer(num_words=features)

# %%
tokenizer.fit_on_texts(cleaned_data)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(cleaned_data)

maxlen=10
padType='post'

X = pad_sequences(sequences, maxlen=maxlen, padding="post", truncating="post")
y = np.asarray(pd.get_dummies(labels))

# %%
len(X), len(y)
# Out:
# (1402, 1402)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle = True)

# %%
word_model = gensim.models.Word2Vec(cleaned_data, vector_size=features, min_count=1, window=3, epochs=50, sg=1)

# %%
print(len(word_model.wv.key_to_index))
# print (embedding_matrix.shape)
# print (X.shape)
# print (y.shape)

print(word_model.wv.most_similar('মৃত্যু'))
# print(word_model.wv.key_to_index)
# print(word_index)
# Out:
# 3806
# [('স্মরণ', 0.9644668102264404), ('প্রতিদিনের', 0.960978627204895), ('বড়', 0.9606923460960388), ('এটির', 0.9604635238647461), ('সবকিছুর', 0.9594570398330688), ('বেশিরভাগ', 0.9594395160675049), ('বছরেরও', 0.9590407609939575), ('মেয়ে', 0.9581333994865417), ('চারপাশের', 0.9579867720603943), ('সম্পাদন', 0.9575933218002319)]

# %%
embedding_matrix = np.zeros((len(word_index) + 1, features))
c = 0
for word, i in word_index.items():
    embedding_vector = word_model.wv[word]
    if embedding_vector is not None:
        c+=1
        embedding_matrix[i] = embedding_vector
print(c)
# Out:
# 3806

# %%
# There are three parameters to the embedding layer
# input_dim : Size of the vocabulary
# output_dim : Length of the vector for each word
# input_length : Maximum length of a sequence

# %%
def get_model(num_of_layer):
    model = Sequential()
    model.add(Embedding(input_dim=len(word_model.wv.key_to_index)+1, output_dim=features, weights=[embedding_matrix], input_length=X.shape[1], trainable=False))
    model.add(Conv1D(filters=features, kernel_size=2, activation='relu'))
    
    for i in range(num_of_layer):
        if i>0:
            model.add(GRU(features, return_sequences=True))
            
    model.add(GRU(features, return_sequences=False))
    model.add(Dense(10, activation="relu"))
    model.add(Dense(y.shape[1], activation="softmax"))
    opt = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    # model.summary()
    return model;

# %%
def run_model(model, batch, epochs):
    history = model.fit(X_train, y_train, batch, epochs, validation_data=(X_test, y_test), verbose=1)
    return history

# %%
#plot

import matplotlib.pyplot as plt

def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# %%
arr_batch = [32]
arr_epochs = [10,20,30]
algo_layers = [1,3,5]
output = {}
idx = 0
for batch in arr_batch:
    for epoch in arr_epochs:
        for layer in algo_layers:
            model = get_model(layer)
            history = run_model(model, batch, epoch)
            ev = model.evaluate(X_test, y_test)
            
            plot_graphs(history, "accuracy")
            plot_graphs(history, "loss")

            y_pred=model.predict(X_test) 
            y_pred=np.argmax(y_pred, axis=1)
            formated_y_test=np.argmax(y_test, axis=1)
            cm = classification_report(formated_y_test, y_pred)
            print(cm)
            
            output[idx] = {'batch':batch, 'epoch':epoch, 'num_of_layer':layer, 'acc':ev, 'cm':cm}
            idx = idx+1;
# Out:
# Epoch 1/10
# 36/36 [==============================] - 5s 49ms/step - loss: 0.6640 - accuracy: 0.7136 - val_loss: 0.6141 - val_accuracy: 0.7972
# Epoch 2/10
# 36/36 [==============================] - 1s 28ms/step - loss: 0.5472 - accuracy: 0.8350 - val_loss: 0.4329 - val_accuracy: 0.8897
# Epoch 3/10
# 36/36 [==============================] - 1s 34ms/step - loss: 0.3416 - accuracy: 0.9001 - val_loss: 0.2894 - val_accuracy: 0.9004
# Epoch 4/10
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2579 - accuracy: 0.8956 - val_loss: 0.3139 - val_accuracy: 0.8754
# Epoch 5/10
# 36/36 [==============================] - 1s 26ms/step - loss: 0.2589 - accuracy: 0.9063 - val_loss: 0.2639 - val_accuracy: 0.9075
# Epoch 6/10
# 36/36 [==============================] - 1s 33ms/step - loss: 0.2356 - accuracy: 0.9153 - val_loss: 0.2524 - val_accuracy: 0.9110
# Epoch 7/10
# 36/36 [==============================] - 1s 28ms/step - loss: 0.2326 - accuracy: 0.9135 - val_loss: 0.2502 - val_accuracy: 0.9075
# Epoch 8/10
# 36/36 [==============================] - 1s 29ms/step - loss: 0.2246 - accuracy: 0.9161 - val_loss: 0.2505 - val_accuracy: 0.9075
# Epoch 9/10
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2188 - accuracy: 0.9179 - val_loss: 0.2459 - val_accuracy: 0.9075
# Epoch 10/10
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2195 - accuracy: 0.9161 - val_loss: 0.2561 - val_accuracy: 0.9075
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2561 - accuracy: 0.9075
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91       135
#            1       0.94      0.88      0.91       146
#
#     accuracy                           0.91       281
#    macro avg       0.91      0.91      0.91       281
# weighted avg       0.91      0.91      0.91       281
#
# Epoch 1/10
# 36/36 [==============================] - 13s 130ms/step - loss: 0.6757 - accuracy: 0.7029 - val_loss: 0.6150 - val_accuracy: 0.8577
# Epoch 2/10
# 36/36 [==============================] - 2s 57ms/step - loss: 0.4292 - accuracy: 0.8724 - val_loss: 0.2972 - val_accuracy: 0.8897
# Epoch 3/10
# 36/36 [==============================] - 2s 62ms/step - loss: 0.2662 - accuracy: 0.9010 - val_loss: 0.2498 - val_accuracy: 0.9110
# Epoch 4/10
# 36/36 [==============================] - 2s 59ms/step - loss: 0.2445 - accuracy: 0.9072 - val_loss: 0.2636 - val_accuracy: 0.8932
# Epoch 5/10
# 36/36 [==============================] - 2s 57ms/step - loss: 0.2408 - accuracy: 0.9117 - val_loss: 0.2432 - val_accuracy: 0.9075
# Epoch 6/10
# 36/36 [==============================] - 2s 58ms/step - loss: 0.2347 - accuracy: 0.9081 - val_loss: 0.2407 - val_accuracy: 0.9075
# Epoch 7/10
# 36/36 [==============================] - 2s 69ms/step - loss: 0.2221 - accuracy: 0.9135 - val_loss: 0.2536 - val_accuracy: 0.9075
# Epoch 8/10
# 36/36 [==============================] - 3s 77ms/step - loss: 0.2235 - accuracy: 0.9179 - val_loss: 0.2389 - val_accuracy: 0.9110
# Epoch 9/10
# 36/36 [==============================] - 2s 67ms/step - loss: 0.2214 - accuracy: 0.9179 - val_loss: 0.2659 - val_accuracy: 0.9004
# Epoch 10/10
# 36/36 [==============================] - 3s 80ms/step - loss: 0.2158 - accuracy: 0.9206 - val_loss: 0.2381 - val_accuracy: 0.9004
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2381 - accuracy: 0.9004
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       135
#            1       0.93      0.88      0.90       146
#
#     accuracy                           0.90       281
#    macro avg       0.90      0.90      0.90       281
# weighted avg       0.90      0.90      0.90       281
#
# Epoch 1/10
# 36/36 [==============================] - 18s 163ms/step - loss: 0.5558 - accuracy: 0.8073 - val_loss: 0.3165 - val_accuracy: 0.8826
# Epoch 2/10
# 36/36 [==============================] - 4s 101ms/step - loss: 0.2700 - accuracy: 0.8947 - val_loss: 0.2577 - val_accuracy: 0.9039
# Epoch 3/10
# 36/36 [==============================] - 4s 101ms/step - loss: 0.2469 - accuracy: 0.9001 - val_loss: 0.2563 - val_accuracy: 0.8897
# Epoch 4/10
# 36/36 [==============================] - 4s 100ms/step - loss: 0.2395 - accuracy: 0.9090 - val_loss: 0.2408 - val_accuracy: 0.9110
# Epoch 5/10
# 36/36 [==============================] - 4s 100ms/step - loss: 0.2288 - accuracy: 0.9144 - val_loss: 0.2564 - val_accuracy: 0.8897
# Epoch 6/10
# 36/36 [==============================] - 4s 100ms/step - loss: 0.2279 - accuracy: 0.9153 - val_loss: 0.2377 - val_accuracy: 0.9075
# Epoch 7/10
# 36/36 [==============================] - 4s 118ms/step - loss: 0.2220 - accuracy: 0.9188 - val_loss: 0.2368 - val_accuracy: 0.9110
# Epoch 8/10
# 36/36 [==============================] - 4s 113ms/step - loss: 0.2213 - accuracy: 0.9179 - val_loss: 0.2345 - val_accuracy: 0.9039
# Epoch 9/10
# 36/36 [==============================] - 4s 100ms/step - loss: 0.2147 - accuracy: 0.9206 - val_loss: 0.2480 - val_accuracy: 0.9075
# Epoch 10/10
# 36/36 [==============================] - 4s 100ms/step - loss: 0.2123 - accuracy: 0.9197 - val_loss: 0.2428 - val_accuracy: 0.9075
# 9/9 [==============================] - 0s 30ms/step - loss: 0.2428 - accuracy: 0.9075
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91       135
#            1       0.94      0.88      0.91       146
#
#     accuracy                           0.91       281
#    macro avg       0.91      0.91      0.91       281
# weighted avg       0.91      0.91      0.91       281
#
# Epoch 1/20
# 36/36 [==============================] - 5s 58ms/step - loss: 0.6748 - accuracy: 0.6869 - val_loss: 0.6361 - val_accuracy: 0.7829
# Epoch 2/20
# 36/36 [==============================] - 1s 29ms/step - loss: 0.5753 - accuracy: 0.8064 - val_loss: 0.4537 - val_accuracy: 0.8861
# Epoch 3/20
# 36/36 [==============================] - 1s 27ms/step - loss: 0.3605 - accuracy: 0.9001 - val_loss: 0.2966 - val_accuracy: 0.8826
# Epoch 4/20
# 36/36 [==============================] - 1s 33ms/step - loss: 0.2636 - accuracy: 0.9045 - val_loss: 0.2773 - val_accuracy: 0.9004
# Epoch 5/20
# 36/36 [==============================] - 1s 33ms/step - loss: 0.2515 - accuracy: 0.9090 - val_loss: 0.2564 - val_accuracy: 0.9110
# Epoch 6/20
# 36/36 [==============================] - 1s 32ms/step - loss: 0.2391 - accuracy: 0.9144 - val_loss: 0.2642 - val_accuracy: 0.9004
# Epoch 7/20
# 36/36 [==============================] - ETA: 0s - loss: 0.2278 - accuracy: 0.91 - 1s 28ms/step - loss: 0.2342 - accuracy: 0.9117 - val_loss: 0.2517 - val_accuracy: 0.9110
# Epoch 8/20
# 36/36 [==============================] - 1s 29ms/step - loss: 0.2285 - accuracy: 0.9179 - val_loss: 0.2466 - val_accuracy: 0.9110
# Epoch 9/20
# 36/36 [==============================] - 1s 42ms/step - loss: 0.2303 - accuracy: 0.9144 - val_loss: 0.2503 - val_accuracy: 0.9039
# Epoch 10/20
# 36/36 [==============================] - 1s 34ms/step - loss: 0.2209 - accuracy: 0.9170 - val_loss: 0.2482 - val_accuracy: 0.9039
# Epoch 11/20
# 36/36 [==============================] - 1s 30ms/step - loss: 0.2257 - accuracy: 0.9179 - val_loss: 0.2325 - val_accuracy: 0.9110
# Epoch 12/20
# 36/36 [==============================] - 1s 31ms/step - loss: 0.2193 - accuracy: 0.9188 - val_loss: 0.2393 - val_accuracy: 0.9075
# Epoch 13/20
# 36/36 [==============================] - 1s 30ms/step - loss: 0.2149 - accuracy: 0.9188 - val_loss: 0.2405 - val_accuracy: 0.9075
# Epoch 14/20
# 36/36 [==============================] - 1s 30ms/step - loss: 0.2235 - accuracy: 0.9135 - val_loss: 0.2652 - val_accuracy: 0.9004
# Epoch 15/20
# 36/36 [==============================] - 1s 32ms/step - loss: 0.2095 - accuracy: 0.9197 - val_loss: 0.2488 - val_accuracy: 0.9075
# Epoch 16/20
# 36/36 [==============================] - 1s 30ms/step - loss: 0.2239 - accuracy: 0.9126 - val_loss: 0.2286 - val_accuracy: 0.9075
# Epoch 17/20
# 36/36 [==============================] - 1s 25ms/step - loss: 0.2097 - accuracy: 0.9224 - val_loss: 0.2361 - val_accuracy: 0.9075
# Epoch 18/20
# 36/36 [==============================] - 1s 25ms/step - loss: 0.2059 - accuracy: 0.9242 - val_loss: 0.2421 - val_accuracy: 0.9110
# Epoch 19/20
# 36/36 [==============================] - 1s 24ms/step - loss: 0.2041 - accuracy: 0.9215 - val_loss: 0.2342 - val_accuracy: 0.9039
# Epoch 20/20
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2024 - accuracy: 0.9269 - val_loss: 0.2408 - val_accuracy: 0.9075
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2408 - accuracy: 0.9075
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91       135
#            1       0.93      0.88      0.91       146
#
#     accuracy                           0.91       281
#    macro avg       0.91      0.91      0.91       281
# weighted avg       0.91      0.91      0.91       281
#
# Epoch 1/20
# 36/36 [==============================] - 11s 112ms/step - loss: 0.6287 - accuracy: 0.7913 - val_loss: 0.4743 - val_accuracy: 0.8790
# Epoch 2/20
# 36/36 [==============================] - 3s 77ms/step - loss: 0.3252 - accuracy: 0.8947 - val_loss: 0.2759 - val_accuracy: 0.8826
# Epoch 3/20
# 36/36 [==============================] - 3s 71ms/step - loss: 0.2551 - accuracy: 0.9054 - val_loss: 0.2620 - val_accuracy: 0.9039
# Epoch 4/20
# 36/36 [==============================] - 2s 69ms/step - loss: 0.2347 - accuracy: 0.9108 - val_loss: 0.2396 - val_accuracy: 0.9075
# Epoch 5/20
# 36/36 [==============================] - 2s 69ms/step - loss: 0.2362 - accuracy: 0.9037 - val_loss: 0.2422 - val_accuracy: 0.8932
# Epoch 6/20
# 36/36 [==============================] - 3s 81ms/step - loss: 0.2317 - accuracy: 0.9144 - val_loss: 0.2452 - val_accuracy: 0.9075
# Epoch 7/20
# 36/36 [==============================] - 3s 94ms/step - loss: 0.2200 - accuracy: 0.9197 - val_loss: 0.2348 - val_accuracy: 0.9110
# Epoch 8/20
# 36/36 [==============================] - 3s 93ms/step - loss: 0.2145 - accuracy: 0.9188 - val_loss: 0.2415 - val_accuracy: 0.9146
# Epoch 9/20
# 36/36 [==============================] - 3s 76ms/step - loss: 0.2836 - accuracy: 0.8885 - val_loss: 0.2740 - val_accuracy: 0.8968
# Epoch 10/20
# 36/36 [==============================] - 3s 73ms/step - loss: 0.2253 - accuracy: 0.9197 - val_loss: 0.2363 - val_accuracy: 0.9075
# Epoch 11/20
# 36/36 [==============================] - 3s 81ms/step - loss: 0.2148 - accuracy: 0.9206 - val_loss: 0.2414 - val_accuracy: 0.9039
# Epoch 12/20
# 36/36 [==============================] - 3s 79ms/step - loss: 0.2134 - accuracy: 0.9197 - val_loss: 0.2434 - val_accuracy: 0.9075
# Epoch 13/20
# 36/36 [==============================] - 3s 84ms/step - loss: 0.2105 - accuracy: 0.9215 - val_loss: 0.2540 - val_accuracy: 0.9075
# Epoch 14/20
# 36/36 [==============================] - 3s 85ms/step - loss: 0.2118 - accuracy: 0.9215 - val_loss: 0.2369 - val_accuracy: 0.9039
# Epoch 15/20
# 36/36 [==============================] - 3s 82ms/step - loss: 0.2034 - accuracy: 0.9233 - val_loss: 0.2380 - val_accuracy: 0.9004
# Epoch 16/20
# 36/36 [==============================] - 4s 121ms/step - loss: 0.2021 - accuracy: 0.9233 - val_loss: 0.2418 - val_accuracy: 0.9075
# Epoch 17/20
# 36/36 [==============================] - 5s 136ms/step - loss: 0.2103 - accuracy: 0.9251 - val_loss: 0.2507 - val_accuracy: 0.9075
# Epoch 18/20
# 36/36 [==============================] - 5s 130ms/step - loss: 0.2007 - accuracy: 0.9269 - val_loss: 0.2385 - val_accuracy: 0.9004
# Epoch 19/20
# 36/36 [==============================] - 5s 131ms/step - loss: 0.2086 - accuracy: 0.9251 - val_loss: 0.2354 - val_accuracy: 0.9004
# Epoch 20/20
# 36/36 [==============================] - 4s 109ms/step - loss: 0.1994 - accuracy: 0.9269 - val_loss: 0.2443 - val_accuracy: 0.9039
# 9/9 [==============================] - 0s 27ms/step - loss: 0.2443 - accuracy: 0.9039
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90       135
#            1       0.93      0.88      0.90       146
#
#     accuracy                           0.90       281
#    macro avg       0.90      0.91      0.90       281
# weighted avg       0.91      0.90      0.90       281
#
# Epoch 1/20
# 36/36 [==============================] - 29s 266ms/step - loss: 0.5591 - accuracy: 0.7226 - val_loss: 0.3539 - val_accuracy: 0.9039
# Epoch 2/20
# 36/36 [==============================] - 6s 170ms/step - loss: 0.2638 - accuracy: 0.9028 - val_loss: 0.2868 - val_accuracy: 0.9110
# Epoch 3/20
# 36/36 [==============================] - 6s 157ms/step - loss: 0.2514 - accuracy: 0.9045 - val_loss: 0.2631 - val_accuracy: 0.8968
# Epoch 4/20
# 36/36 [==============================] - 5s 153ms/step - loss: 0.2391 - accuracy: 0.9054 - val_loss: 0.3111 - val_accuracy: 0.8826
# Epoch 5/20
# 36/36 [==============================] - 5s 152ms/step - loss: 0.2348 - accuracy: 0.9108 - val_loss: 0.2741 - val_accuracy: 0.9004
# Epoch 6/20
# 36/36 [==============================] - 6s 156ms/step - loss: 0.2208 - accuracy: 0.9135 - val_loss: 0.2438 - val_accuracy: 0.9075
# Epoch 7/20
# 36/36 [==============================] - 5s 144ms/step - loss: 0.2144 - accuracy: 0.9197 - val_loss: 0.2456 - val_accuracy: 0.9039
# Epoch 8/20
# 36/36 [==============================] - 5s 149ms/step - loss: 0.2108 - accuracy: 0.9224 - val_loss: 0.2402 - val_accuracy: 0.9039
# Epoch 9/20
# 36/36 [==============================] - 5s 144ms/step - loss: 0.2082 - accuracy: 0.9224 - val_loss: 0.2378 - val_accuracy: 0.9039
# Epoch 10/20
# 36/36 [==============================] - 5s 145ms/step - loss: 0.2033 - accuracy: 0.9233 - val_loss: 0.2464 - val_accuracy: 0.9039
# Epoch 11/20
# 36/36 [==============================] - 6s 155ms/step - loss: 0.2094 - accuracy: 0.9179 - val_loss: 0.2601 - val_accuracy: 0.9039
# Epoch 12/20
# 36/36 [==============================] - 5s 151ms/step - loss: 0.1971 - accuracy: 0.9286 - val_loss: 0.2577 - val_accuracy: 0.9039
# Epoch 13/20
# 36/36 [==============================] - 5s 147ms/step - loss: 0.2003 - accuracy: 0.9260 - val_loss: 0.2399 - val_accuracy: 0.9039
# Epoch 14/20
# 36/36 [==============================] - 5s 149ms/step - loss: 0.1956 - accuracy: 0.9286 - val_loss: 0.2607 - val_accuracy: 0.9004
# Epoch 15/20
# 36/36 [==============================] - 6s 155ms/step - loss: 0.1980 - accuracy: 0.9260 - val_loss: 0.2501 - val_accuracy: 0.9039
# Epoch 16/20
# 36/36 [==============================] - 4s 117ms/step - loss: 0.1932 - accuracy: 0.9295 - val_loss: 0.2380 - val_accuracy: 0.9075
# Epoch 17/20
# 36/36 [==============================] - 5s 138ms/step - loss: 0.1942 - accuracy: 0.9277 - val_loss: 0.2400 - val_accuracy: 0.9004
# Epoch 18/20
# 36/36 [==============================] - 4s 110ms/step - loss: 0.1855 - accuracy: 0.9313 - val_loss: 0.2534 - val_accuracy: 0.9004
# Epoch 19/20
# 36/36 [==============================] - 4s 114ms/step - loss: 0.1846 - accuracy: 0.9286 - val_loss: 0.2571 - val_accuracy: 0.9039
# Epoch 20/20
# 36/36 [==============================] - 4s 121ms/step - loss: 0.1840 - accuracy: 0.9322 - val_loss: 0.2466 - val_accuracy: 0.9004
# 9/9 [==============================] - 0s 41ms/step - loss: 0.2466 - accuracy: 0.9004
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       135
#            1       0.92      0.88      0.90       146
#
#     accuracy                           0.90       281
#    macro avg       0.90      0.90      0.90       281
# weighted avg       0.90      0.90      0.90       281
#
# Epoch 1/30
# 36/36 [==============================] - 5s 50ms/step - loss: 0.6748 - accuracy: 0.7083 - val_loss: 0.6376 - val_accuracy: 0.7900
# Epoch 2/30
# 36/36 [==============================] - 1s 34ms/step - loss: 0.5856 - accuracy: 0.8216 - val_loss: 0.4745 - val_accuracy: 0.8826
# Epoch 3/30
# 36/36 [==============================] - 1s 38ms/step - loss: 0.3532 - accuracy: 0.9028 - val_loss: 0.2699 - val_accuracy: 0.9004
# Epoch 4/30
# 36/36 [==============================] - 1s 35ms/step - loss: 0.2504 - accuracy: 0.9072 - val_loss: 0.2799 - val_accuracy: 0.8932
# Epoch 5/30
# 36/36 [==============================] - 1s 29ms/step - loss: 0.2415 - accuracy: 0.9090 - val_loss: 0.2503 - val_accuracy: 0.9039
# Epoch 6/30
# 36/36 [==============================] - 1s 27ms/step - loss: 0.2360 - accuracy: 0.9161 - val_loss: 0.2537 - val_accuracy: 0.9110
# Epoch 7/30
# 36/36 [==============================] - 1s 25ms/step - loss: 0.2287 - accuracy: 0.9144 - val_loss: 0.2513 - val_accuracy: 0.9075
# Epoch 8/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.2223 - accuracy: 0.9170 - val_loss: 0.2613 - val_accuracy: 0.9039
# Epoch 9/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.2215 - accuracy: 0.9179 - val_loss: 0.2509 - val_accuracy: 0.9039
# Epoch 10/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.2167 - accuracy: 0.9188 - val_loss: 0.2610 - val_accuracy: 0.9039
# Epoch 11/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.2198 - accuracy: 0.9179 - val_loss: 0.2436 - val_accuracy: 0.9039
# Epoch 12/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.2125 - accuracy: 0.9188 - val_loss: 0.2385 - val_accuracy: 0.9039
# Epoch 13/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.2126 - accuracy: 0.9197 - val_loss: 0.2418 - val_accuracy: 0.9039
# Epoch 14/30
# 36/36 [==============================] - 1s 25ms/step - loss: 0.2129 - accuracy: 0.9215 - val_loss: 0.2488 - val_accuracy: 0.9039
# Epoch 15/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.2054 - accuracy: 0.9233 - val_loss: 0.2504 - val_accuracy: 0.9004
# Epoch 16/30
# 36/36 [==============================] - 1s 25ms/step - loss: 0.2008 - accuracy: 0.9260 - val_loss: 0.2471 - val_accuracy: 0.9004
# Epoch 17/30
# 36/36 [==============================] - 1s 25ms/step - loss: 0.1993 - accuracy: 0.9260 - val_loss: 0.2453 - val_accuracy: 0.9075
# Epoch 18/30
# 36/36 [==============================] - 1s 25ms/step - loss: 0.1982 - accuracy: 0.9286 - val_loss: 0.2499 - val_accuracy: 0.8968
# Epoch 19/30
# 36/36 [==============================] - 1s 25ms/step - loss: 0.1943 - accuracy: 0.9295 - val_loss: 0.2433 - val_accuracy: 0.9075
# Epoch 20/30
# 36/36 [==============================] - 1s 25ms/step - loss: 0.1948 - accuracy: 0.9295 - val_loss: 0.2445 - val_accuracy: 0.9039
# Epoch 21/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.1934 - accuracy: 0.9277 - val_loss: 0.2496 - val_accuracy: 0.9039
# Epoch 22/30
# 36/36 [==============================] - 1s 25ms/step - loss: 0.1927 - accuracy: 0.9304 - val_loss: 0.2485 - val_accuracy: 0.9004
# Epoch 23/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.1906 - accuracy: 0.9313 - val_loss: 0.2569 - val_accuracy: 0.8968
# Epoch 24/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.1892 - accuracy: 0.9313 - val_loss: 0.2831 - val_accuracy: 0.8968
# Epoch 25/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.1882 - accuracy: 0.9313 - val_loss: 0.2525 - val_accuracy: 0.9004
# Epoch 26/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.1848 - accuracy: 0.9313 - val_loss: 0.2498 - val_accuracy: 0.9004
# Epoch 27/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.1839 - accuracy: 0.9331 - val_loss: 0.2548 - val_accuracy: 0.9004
# Epoch 28/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.1839 - accuracy: 0.9331 - val_loss: 0.2811 - val_accuracy: 0.8968
# Epoch 29/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.1867 - accuracy: 0.9260 - val_loss: 0.2592 - val_accuracy: 0.9075
# Epoch 30/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.1904 - accuracy: 0.9269 - val_loss: 0.2689 - val_accuracy: 0.8932
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2689 - accuracy: 0.8932
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89       135
#            1       0.92      0.87      0.89       146
#
#     accuracy                           0.89       281
#    macro avg       0.89      0.89      0.89       281
# weighted avg       0.89      0.89      0.89       281
#
# Epoch 1/30
# 36/36 [==============================] - 11s 111ms/step - loss: 0.6662 - accuracy: 0.7645 - val_loss: 0.5818 - val_accuracy: 0.8399
# Epoch 2/30
# 36/36 [==============================] - 2s 65ms/step - loss: 0.4496 - accuracy: 0.8644 - val_loss: 0.3025 - val_accuracy: 0.9039
# Epoch 3/30
# 36/36 [==============================] - 2s 64ms/step - loss: 0.2676 - accuracy: 0.9037 - val_loss: 0.2703 - val_accuracy: 0.9004
# Epoch 4/30
# 36/36 [==============================] - 2s 64ms/step - loss: 0.2540 - accuracy: 0.9072 - val_loss: 0.2489 - val_accuracy: 0.9075
# Epoch 5/30
# 36/36 [==============================] - 2s 65ms/step - loss: 0.2366 - accuracy: 0.9153 - val_loss: 0.2447 - val_accuracy: 0.9075
# Epoch 6/30
# 36/36 [==============================] - 2s 64ms/step - loss: 0.2307 - accuracy: 0.9144 - val_loss: 0.2432 - val_accuracy: 0.9075
# Epoch 7/30
# 36/36 [==============================] - 3s 70ms/step - loss: 0.2243 - accuracy: 0.9179 - val_loss: 0.2446 - val_accuracy: 0.9110
# Epoch 8/30
# 36/36 [==============================] - 2s 65ms/step - loss: 0.2190 - accuracy: 0.9179 - val_loss: 0.2597 - val_accuracy: 0.8897
# Epoch 9/30
# 36/36 [==============================] - 3s 76ms/step - loss: 0.2232 - accuracy: 0.9170 - val_loss: 0.2391 - val_accuracy: 0.9146
# Epoch 10/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.2129 - accuracy: 0.9215 - val_loss: 0.2495 - val_accuracy: 0.9039
# Epoch 11/30
# 36/36 [==============================] - 2s 67ms/step - loss: 0.2121 - accuracy: 0.9224 - val_loss: 0.2435 - val_accuracy: 0.9146
# Epoch 12/30
# 36/36 [==============================] - 2s 65ms/step - loss: 0.2081 - accuracy: 0.9233 - val_loss: 0.2422 - val_accuracy: 0.9075
# Epoch 13/30
# 36/36 [==============================] - 2s 66ms/step - loss: 0.2053 - accuracy: 0.9233 - val_loss: 0.2456 - val_accuracy: 0.9039
# Epoch 14/30
# 36/36 [==============================] - 3s 91ms/step - loss: 0.1997 - accuracy: 0.9260 - val_loss: 0.2577 - val_accuracy: 0.9075
# Epoch 15/30
# 36/36 [==============================] - 3s 89ms/step - loss: 0.2014 - accuracy: 0.9251 - val_loss: 0.2558 - val_accuracy: 0.8968
# Epoch 16/30
# 36/36 [==============================] - 3s 83ms/step - loss: 0.1972 - accuracy: 0.9269 - val_loss: 0.2512 - val_accuracy: 0.9075
# Epoch 17/30
# 36/36 [==============================] - 3s 73ms/step - loss: 0.1978 - accuracy: 0.9269 - val_loss: 0.2481 - val_accuracy: 0.9004
# Epoch 18/30
# 36/36 [==============================] - 3s 77ms/step - loss: 0.1923 - accuracy: 0.9295 - val_loss: 0.2584 - val_accuracy: 0.8932
# Epoch 19/30
# 36/36 [==============================] - 3s 78ms/step - loss: 0.1888 - accuracy: 0.9304 - val_loss: 0.2573 - val_accuracy: 0.8968
# Epoch 20/30
# 36/36 [==============================] - 3s 73ms/step - loss: 0.2234 - accuracy: 0.9161 - val_loss: 0.2610 - val_accuracy: 0.9039
# Epoch 21/30
# 36/36 [==============================] - 3s 72ms/step - loss: 0.1941 - accuracy: 0.9304 - val_loss: 0.2681 - val_accuracy: 0.9004
# Epoch 22/30
# 36/36 [==============================] - 3s 72ms/step - loss: 0.1921 - accuracy: 0.9286 - val_loss: 0.2909 - val_accuracy: 0.8968
# Epoch 23/30
# 36/36 [==============================] - 3s 73ms/step - loss: 0.1874 - accuracy: 0.9313 - val_loss: 0.2542 - val_accuracy: 0.9004
# Epoch 24/30
# 36/36 [==============================] - 3s 72ms/step - loss: 0.1847 - accuracy: 0.9331 - val_loss: 0.2612 - val_accuracy: 0.8968
# Epoch 25/30
# 36/36 [==============================] - 3s 72ms/step - loss: 0.1833 - accuracy: 0.9331 - val_loss: 0.2668 - val_accuracy: 0.8932
# Epoch 26/30
# 36/36 [==============================] - 3s 72ms/step - loss: 0.1832 - accuracy: 0.9313 - val_loss: 0.2463 - val_accuracy: 0.9075
# Epoch 27/30
# 36/36 [==============================] - 3s 72ms/step - loss: 0.1826 - accuracy: 0.9331 - val_loss: 0.2591 - val_accuracy: 0.9039
# Epoch 28/30
# 36/36 [==============================] - 3s 72ms/step - loss: 0.1767 - accuracy: 0.9340 - val_loss: 0.2525 - val_accuracy: 0.9039
# Epoch 29/30
# 36/36 [==============================] - 3s 71ms/step - loss: 0.1734 - accuracy: 0.9349 - val_loss: 0.2508 - val_accuracy: 0.9039
# Epoch 30/30
# 36/36 [==============================] - 3s 72ms/step - loss: 0.1732 - accuracy: 0.9340 - val_loss: 0.2581 - val_accuracy: 0.9075
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2581 - accuracy: 0.9075
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91       135
#            1       0.92      0.90      0.91       146
#
#     accuracy                           0.91       281
#    macro avg       0.91      0.91      0.91       281
# weighted avg       0.91      0.91      0.91       281
#
# Epoch 1/30
# 36/36 [==============================] - 20s 171ms/step - loss: 0.6256 - accuracy: 0.5772 - val_loss: 0.5222 - val_accuracy: 0.8078
# Epoch 2/30
# 36/36 [==============================] - 4s 108ms/step - loss: 0.4870 - accuracy: 0.8956 - val_loss: 0.4856 - val_accuracy: 0.8968
# Epoch 3/30
# 36/36 [==============================] - 4s 108ms/step - loss: 0.4722 - accuracy: 0.9037 - val_loss: 0.4750 - val_accuracy: 0.9110
# Epoch 4/30
# 36/36 [==============================] - 4s 108ms/step - loss: 0.4554 - accuracy: 0.9117 - val_loss: 0.4503 - val_accuracy: 0.9075
# Epoch 5/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.4035 - accuracy: 0.9019 - val_loss: 0.3655 - val_accuracy: 0.8861
# Epoch 6/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.3397 - accuracy: 0.8805 - val_loss: 0.3311 - val_accuracy: 0.8826
# Epoch 7/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.2905 - accuracy: 0.8965 - val_loss: 0.3245 - val_accuracy: 0.8754
# Epoch 8/30
# 36/36 [==============================] - 4s 106ms/step - loss: 0.2736 - accuracy: 0.9010 - val_loss: 0.3177 - val_accuracy: 0.8754
# Epoch 9/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.2602 - accuracy: 0.9010 - val_loss: 0.3102 - val_accuracy: 0.8790
# Epoch 10/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.2574 - accuracy: 0.9054 - val_loss: 0.2948 - val_accuracy: 0.8826
# Epoch 11/30
# 36/36 [==============================] - 4s 108ms/step - loss: 0.2379 - accuracy: 0.9206 - val_loss: 0.2788 - val_accuracy: 0.8968
# Epoch 12/30
# 36/36 [==============================] - 4s 109ms/step - loss: 0.2276 - accuracy: 0.9197 - val_loss: 0.2723 - val_accuracy: 0.9004
# Epoch 13/30
# 36/36 [==============================] - 4s 125ms/step - loss: 0.2221 - accuracy: 0.9179 - val_loss: 0.2601 - val_accuracy: 0.9039
# Epoch 14/30
# 36/36 [==============================] - 4s 121ms/step - loss: 0.2345 - accuracy: 0.9054 - val_loss: 0.2656 - val_accuracy: 0.8754
# Epoch 15/30
# 36/36 [==============================] - 4s 106ms/step - loss: 0.2240 - accuracy: 0.9090 - val_loss: 0.2700 - val_accuracy: 0.8790
# Epoch 16/30
# 36/36 [==============================] - 4s 108ms/step - loss: 0.2131 - accuracy: 0.9108 - val_loss: 0.2591 - val_accuracy: 0.8754
# Epoch 17/30
# 36/36 [==============================] - 4s 106ms/step - loss: 0.2063 - accuracy: 0.9144 - val_loss: 0.2601 - val_accuracy: 0.8790
# Epoch 18/30
# 36/36 [==============================] - 4s 108ms/step - loss: 0.1987 - accuracy: 0.9197 - val_loss: 0.2630 - val_accuracy: 0.8932
# Epoch 19/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.1941 - accuracy: 0.9304 - val_loss: 0.2570 - val_accuracy: 0.9004
# Epoch 20/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.1848 - accuracy: 0.9349 - val_loss: 0.2743 - val_accuracy: 0.9039
# Epoch 21/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.1827 - accuracy: 0.9384 - val_loss: 0.2703 - val_accuracy: 0.8968
# Epoch 22/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.1766 - accuracy: 0.9438 - val_loss: 0.2780 - val_accuracy: 0.9039
# Epoch 23/30
# 36/36 [==============================] - 4s 106ms/step - loss: 0.1752 - accuracy: 0.9367 - val_loss: 0.2740 - val_accuracy: 0.9075
# Epoch 24/30
# 36/36 [==============================] - 4s 108ms/step - loss: 0.1881 - accuracy: 0.9340 - val_loss: 0.2586 - val_accuracy: 0.9110
# Epoch 25/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.1804 - accuracy: 0.9340 - val_loss: 0.2685 - val_accuracy: 0.9039
# Epoch 26/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.1732 - accuracy: 0.9376 - val_loss: 0.2580 - val_accuracy: 0.9004
# Epoch 27/30
# 36/36 [==============================] - 4s 109ms/step - loss: 0.1678 - accuracy: 0.9411 - val_loss: 0.2814 - val_accuracy: 0.8932
# Epoch 28/30
# 36/36 [==============================] - 4s 109ms/step - loss: 0.1656 - accuracy: 0.9429 - val_loss: 0.2804 - val_accuracy: 0.9004
# Epoch 29/30
# 36/36 [==============================] - 4s 107ms/step - loss: 0.1586 - accuracy: 0.9438 - val_loss: 0.3090 - val_accuracy: 0.9039
# Epoch 30/30
# 36/36 [==============================] - 4s 108ms/step - loss: 0.1648 - accuracy: 0.9393 - val_loss: 0.2956 - val_accuracy: 0.9004
# 9/9 [==============================] - 0s 36ms/step - loss: 0.2956 - accuracy: 0.9004
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90       135
#            1       0.92      0.89      0.90       146
#
#     accuracy                           0.90       281
#    macro avg       0.90      0.90      0.90       281
# weighted avg       0.90      0.90      0.90       281

# %%
output
# Out:
# {0: {'batch': 32,
#   'epoch': 10,
#   'num_of_layer': 1,
#   'acc': [0.2560672163963318, 0.9074733257293701],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.88      0.94      0.91       135\n           1       0.94      0.88      0.91       146\n\n    accuracy                           0.91       281\n   macro avg       0.91      0.91      0.91       281\nweighted avg       0.91      0.91      0.91       281\n'},
#  1: {'batch': 32,
#   'epoch': 10,
#   'num_of_layer': 3,
#   'acc': [0.23808489739894867, 0.900355875492096],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.87      0.93      0.90       135\n           1       0.93      0.88      0.90       146\n\n    accuracy                           0.90       281\n   macro avg       0.90      0.90      0.90       281\nweighted avg       0.90      0.90      0.90       281\n'},
#  2: {'batch': 32,
#   'epoch': 10,
#   'num_of_layer': 5,
#   'acc': [0.2428065985441208, 0.9074733257293701],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.88      0.94      0.91       135\n           1       0.94      0.88      0.91       146\n\n    accuracy                           0.91       281\n   macro avg       0.91      0.91      0.91       281\nweighted avg       0.91      0.91      0.91       281\n'},
#  3: {'batch': 32,
#   'epoch': 20,
#   'num_of_layer': 1,
#   'acc': [0.24078980088233948, 0.9074733257293701],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.88      0.93      0.91       135\n           1       0.93      0.88      0.91       146\n\n    accuracy                           0.91       281\n   macro avg       0.91      0.91      0.91       281\nweighted avg       0.91      0.91      0.91       281\n'},
#  4: {'batch': 32,
#   'epoch': 20,
#   'num_of_layer': 3,
#   'acc': [0.24432732164859772, 0.9039145708084106],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.88      0.93      0.90       135\n           1       0.93      0.88      0.90       146\n\n    accuracy                           0.90       281\n   macro avg       0.90      0.91      0.90       281\nweighted avg       0.91      0.90      0.90       281\n'},
#  5: {'batch': 32,
#   'epoch': 20,
#   'num_of_layer': 5,
#   'acc': [0.24664421379566193, 0.900355875492096],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.88      0.92      0.90       135\n           1       0.92      0.88      0.90       146\n\n    accuracy                           0.90       281\n   macro avg       0.90      0.90      0.90       281\nweighted avg       0.90      0.90      0.90       281\n'},
#  6: {'batch': 32,
#   'epoch': 30,
#   'num_of_layer': 1,
#   'acc': [0.26886940002441406, 0.8932384252548218],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.87      0.92      0.89       135\n           1       0.92      0.87      0.89       146\n\n    accuracy                           0.89       281\n   macro avg       0.89      0.89      0.89       281\nweighted avg       0.89      0.89      0.89       281\n'},
#  7: {'batch': 32,
#   'epoch': 30,
#   'num_of_layer': 3,
#   'acc': [0.25805288553237915, 0.9074733257293701],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.89      0.92      0.91       135\n           1       0.92      0.90      0.91       146\n\n    accuracy                           0.91       281\n   macro avg       0.91      0.91      0.91       281\nweighted avg       0.91      0.91      0.91       281\n'},
#  8: {'batch': 32,
#   'epoch': 30,
#   'num_of_layer': 5,
#   'acc': [0.29563474655151367, 0.900355875492096],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.88      0.91      0.90       135\n           1       0.92      0.89      0.90       146\n\n    accuracy                           0.90       281\n   macro avg       0.90      0.90      0.90       281\nweighted avg       0.90      0.90      0.90       281\n'}}

# %%
import json
json_object = json.dumps(output, indent = 4)
with open('model_v0.0.0_sg_cnn_gru_dense.json', 'a') as fp:
    fp.write(json_object)
