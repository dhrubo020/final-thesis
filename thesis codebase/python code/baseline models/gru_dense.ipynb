# %%
import tensorflow as tf
keras = tf.keras
import warnings
warnings.filterwarnings("ignore")
import gensim, re
import numpy as np
import pandas as pd
import openpyxl
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences 
from tensorflow.keras.models import load_model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Embedding, Bidirectional, Dropout, Conv1D

# %%
main_data = pd.read_excel( r"C:\Users\Dhrubo\1_Thesis\data_v2\suicide_data.xlsx", sheet_name="Sheet1" )
print(main_data.columns.ravel())
posts = main_data['text'].tolist()
labels = main_data['label'].tolist()
# Out:
# ['text' 'label']

# %%
from nltk.tokenize import word_tokenize

def clean_text(data):
    all_data = list()
    final_data = list()
    stopwords_bn = ["অতএব","অথচ","অথবা","অনুযায়ী","অনেক","অনেকে","অনেকেই","অন্তত","অন্য","অবধি","অবশ্য","অর্থাত","আই","আগামী","আগে","আগেই","আছে","আজ","আদ্যভাগে","আপনার","আপনি","আবার","আমরা","আমাকে","আমাদের","আমার","আমি","আর","আরও","ই","ইত্যাদি","ইহা","উচিত","উত্তর","উনি","উপর","উপরে","এ","এঁদের","এঁরা","এই","একই","একটি","একবার","একে","এক্","এখন","এখনও","এখানে","এখানেই","এটা","এটাই","এটি","এত","এতটাই","এতে","এদের","এব","এবং","এবার","এমন","এমনকী","এমনি","এর","এরা","এল","এস","এসে","ঐ","ও","ওঁদের","ওঁর","ওঁরা","ওই","ওকে","ওখানে","ওদের","ওর","ওরা","কখনও","কত","কবে","কমনে","কয়েক","কয়েকটি","করছে","করছেন","করতে","করবে","করবেন","করলে","করলেন","করা","করাই","করায়","করার","করি","করিতে","করিয়া","করিয়ে","করে","করেই","করেছিলেন","করেছে","করেছেন","করেন","কাউকে","কাছ","কাছে","কাজ","কাজে","কারও","কারণ","কি","কিংবা","কিছু","কিছুই","কিন্তু","কী","কে","কেউ","কেউই","কেখা","কেন","কোটি","কোন","কোনও","কোনো","ক্ষেত্রে","কয়েক","খুব","গিয়ে","গিয়েছে","গিয়ে","গুলি","গেছে","গেল","গেলে","গোটা","চলে","চান","চায়","চার","চালু","চেয়ে","চেষ্টা","ছাড়া","ছাড়াও","ছিল","ছিলেন","জন","জনকে","জনের","জন্য","জন্যওজে","জানতে","জানা","জানানো","জানায়","জানিয়ে","জানিয়েছে","জে","জ্নজন","টি","ঠিক","তখন","তত","তথা","তবু","তবে","তা","তাঁকে","তাঁদের","তাঁর","তাঁরা","তাঁাহারা","তাই","তাও","তাকে","তাতে","তাদের","তার","তারপর","তারা","তারৈ","তাহলে","তাহা","তাহাতে","তাহার","তিনঐ","তিনি","তিনিও","তুমি","তুলে","তেমন","তো","তোমার","থাকবে","থাকবেন","থাকা","থাকায়","থাকে","থাকেন","থেকে","থেকেই","থেকেও","দিকে","দিতে","দিন","দিয়ে","দিয়েছে","দিয়েছেন","দিলেন","দু","দুই","দুটি","দুটো","দেওয়া","দেওয়ার","দেওয়া","দেখতে","দেখা","দেখে","দেন","দেয়","দ্বারা","ধরা","ধরে","ধামার","নতুন","নাকি","নাগাদ","নানা","নিজে","নিজেই","নিজেদের","নিজের","নিতে","নিয়ে","নিয়ে","নেওয়া","নেওয়ার","নেওয়া","নয়","পক্ষে","পর","পরে","পরেই","পরেও","পর্যন্ত","পাওয়া","পাচ","পারি","পারে","পারেন","পি","পেয়ে","পেয়্র্","প্রতি","প্রথম","প্রভৃতি","প্রযন্ত","প্রাথমিক","প্রায়","প্রায়","ফলে","ফিরে","ফের","বক্তব্য","বদলে","বন","বরং","বলতে","বলল","বললেন","বলা","বলে","বলেছেন","বলেন","বসে","বহু","বা","বাদে","বার","বি","বিনা","বিভিন্ন","বিশেষ","বিষয়টি","বেশ","বেশি","ব্যবহার","ব্যাপারে","ভাবে","ভাবেই","মতো","মতোই","মধ্যভাগে","মধ্যে","মধ্যেই","মধ্যেও","মনে","মাত্র","মাধ্যমে","মোট","মোটেই","যখন","যত","যতটা","যথেষ্ট","যদি","যদিও","যা","যাঁর","যাঁরা","যাওয়া","যাওয়ার","যাওয়া","যাকে","যাচ্ছে","যাতে","যাদের","যান","যাবে","যায়","যার","যারা","যিনি","যে","যেখানে","যেতে","যেন","যেমন","র","রকম","রয়েছে","রাখা","রেখে","লক্ষ","শুধু","শুরু","সঙ্গে","সঙ্গেও","সব","সবার","সমস্ত","সম্প্রতি","সহ","সহিত","সাধারণ","সামনে","সি","সুতরাং","সে","সেই","সেখান","সেখানে","সেটা","সেটাই","সেটাও","সেটি","স্পষ্ট","স্বয়ং","হইতে","হইবে","হইয়া","হওয়া","হওয়ায়","হওয়ার","হচ্ছে","হত","হতে","হতেই","হন","হবে","হবেন","হয়","হয়তো","হয়নি","হয়ে","হয়েই","হয়েছিল","হয়েছে","হয়েছেন","হল","হলে","হলেই","হলেও","হলো","হাজার","হিসাবে","হৈলে","হোক","হয়"]
    lines = [re.sub(r'[^\u0980-\u09FF]+',' ',sentence) for sentence in data]
    lines = [re.sub(r'[\u09E6-\u09EF]+','',sentence) for sentence in data]
    lines = [re.sub(r'[0-9a-zA-Z]+','',sentence) for sentence in data]
    for text in lines: 
        pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
        text = pattern.sub('', text)
        
        emoji = re.compile("["
                           u"\U0001F600-\U0001FFFF"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
        text = emoji.sub(r'', text)
        
        text = re.sub(r"[।“,”'’‘.\"!@#$%^&*(){}?/;`~:<>+=-]", "", text)
        text = re.sub(r"\s+$", "", text)
        text = re.sub(r"^\s", "", text)
        tokens = word_tokenize(text)
        words = [w for w in tokens if not w in stopwords_bn]
        all_data.append(words) 
    
#     removing numbers and empty words
    for line in all_data:
            line = [re.sub(r'[\u09E6-\u09EF]+','',word) for word in line]
            line = [w for w in line if not w == '']
            final_data.append(line)
    
    return final_data

# %%
cleaned_data = clean_text(posts)

# %%
features = 100
tokenizer = Tokenizer(num_words=features)

# %%
tokenizer.fit_on_texts(cleaned_data)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(cleaned_data)

maxlen=10
padType='post'

X = pad_sequences(sequences, maxlen=maxlen, padding="post", truncating="post")
y = np.asarray(pd.get_dummies(labels))

# %%
len(X), len(y)
# Out:
# (1402, 1402)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle = True)

# %%
def get_model(num_of_layer):
    model = Sequential()
    model.add(Embedding(4000, features, input_length = X.shape[1]))
    
    for i in range(num_of_layer):
        if i>0:
            model.add(GRU(features, return_sequences=True))
            
    model.add(GRU(features, return_sequences=False))
    model.add(Dense(10, activation="relu"))
    model.add(Dense(y.shape[1], activation="softmax"))
    opt = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    # model.summary()
    return model;

# %%
def run_model(model, batch, epochs):
    history = model.fit(X_train, y_train, batch, epochs, validation_data=(X_test, y_test), verbose=1)
    return history

# %%
#plot

import matplotlib.pyplot as plt

def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# %%
arr_batch = [32]
arr_epochs = [10,20,30]
algo_layers = [1,3,5]
output = {}
idx = 0
for batch in arr_batch:
    for epoch in arr_epochs:
        for layer in algo_layers:
            model = get_model(layer)
            history = run_model(model, batch, epoch)
            ev = model.evaluate(X_test, y_test)
            
            plot_graphs(history, "accuracy")
            plot_graphs(history, "loss")

            y_pred=model.predict(X_test) 
            y_pred=np.argmax(y_pred, axis=1)
            formated_y_test=np.argmax(y_test, axis=1)
            cm = classification_report(formated_y_test, y_pred)
            print(cm)
            
            output[idx] = {'batch':batch, 'epoch':epoch, 'num_of_layer':layer, 'acc':ev, 'cm':cm}
            idx = idx+1;
# Out:
# Epoch 1/10
# 36/36 [==============================] - 6s 42ms/step - loss: 0.6935 - accuracy: 0.4978 - val_loss: 0.6932 - val_accuracy: 0.4982
# Epoch 2/10
# 36/36 [==============================] - 1s 19ms/step - loss: 0.6932 - accuracy: 0.4969 - val_loss: 0.6929 - val_accuracy: 0.5053
# Epoch 3/10
# 36/36 [==============================] - 1s 19ms/step - loss: 0.6930 - accuracy: 0.5183 - val_loss: 0.6926 - val_accuracy: 0.5053
# Epoch 4/10
# 36/36 [==============================] - 1s 19ms/step - loss: 0.6926 - accuracy: 0.4987 - val_loss: 0.6921 - val_accuracy: 0.5053
# Epoch 5/10
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6923 - accuracy: 0.4987 - val_loss: 0.6910 - val_accuracy: 0.5053
# Epoch 6/10
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6905 - accuracy: 0.4987 - val_loss: 0.6881 - val_accuracy: 0.5053
# Epoch 7/10
# 36/36 [==============================] - 1s 24ms/step - loss: 0.6856 - accuracy: 0.5201 - val_loss: 0.6814 - val_accuracy: 0.5053
# Epoch 8/10
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6708 - accuracy: 0.5468 - val_loss: 0.6466 - val_accuracy: 0.5658
# Epoch 9/10
# 36/36 [==============================] - 1s 23ms/step - loss: 0.5962 - accuracy: 0.6441 - val_loss: 0.5228 - val_accuracy: 0.7900
# Epoch 10/10
# 36/36 [==============================] - 1s 20ms/step - loss: 0.4851 - accuracy: 0.8466 - val_loss: 0.4748 - val_accuracy: 0.8541
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4748 - accuracy: 0.8541
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85       139
#            1       0.83      0.90      0.86       142
#
#     accuracy                           0.85       281
#    macro avg       0.86      0.85      0.85       281
# weighted avg       0.86      0.85      0.85       281
#
# Epoch 1/10
# 36/36 [==============================] - 13s 94ms/step - loss: 0.6928 - accuracy: 0.5040 - val_loss: 0.6915 - val_accuracy: 0.5231
# Epoch 2/10
# 36/36 [==============================] - 2s 45ms/step - loss: 0.6907 - accuracy: 0.5236 - val_loss: 0.6893 - val_accuracy: 0.5445
# Epoch 3/10
# 36/36 [==============================] - 1s 41ms/step - loss: 0.6875 - accuracy: 0.5620 - val_loss: 0.6834 - val_accuracy: 0.6050
# Epoch 4/10
# 36/36 [==============================] - 1s 39ms/step - loss: 0.6710 - accuracy: 0.6307 - val_loss: 0.6458 - val_accuracy: 0.6975
# Epoch 5/10
# 36/36 [==============================] - 2s 46ms/step - loss: 0.5689 - accuracy: 0.7654 - val_loss: 0.4624 - val_accuracy: 0.8612
# Epoch 6/10
# 36/36 [==============================] - 2s 44ms/step - loss: 0.3567 - accuracy: 0.8689 - val_loss: 0.3465 - val_accuracy: 0.8470
# Epoch 7/10
# 36/36 [==============================] - 1s 39ms/step - loss: 0.2825 - accuracy: 0.8894 - val_loss: 0.3000 - val_accuracy: 0.8826
# Epoch 8/10
# 36/36 [==============================] - 1s 39ms/step - loss: 0.2571 - accuracy: 0.8974 - val_loss: 0.2734 - val_accuracy: 0.8790
# Epoch 9/10
# 36/36 [==============================] - 2s 42ms/step - loss: 0.2464 - accuracy: 0.9001 - val_loss: 0.2677 - val_accuracy: 0.8861
# Epoch 10/10
# 36/36 [==============================] - 2s 48ms/step - loss: 0.2395 - accuracy: 0.9010 - val_loss: 0.2636 - val_accuracy: 0.8932
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2636 - accuracy: 0.8932
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90       139
#            1       0.92      0.87      0.89       142
#
#     accuracy                           0.89       281
#    macro avg       0.89      0.89      0.89       281
# weighted avg       0.89      0.89      0.89       281
#
# Epoch 1/10
# 36/36 [==============================] - 28s 228ms/step - loss: 0.6916 - accuracy: 0.5442 - val_loss: 0.6886 - val_accuracy: 0.5730
# Epoch 2/10
# 36/36 [==============================] - 2s 66ms/step - loss: 0.6787 - accuracy: 0.6735 - val_loss: 0.6558 - val_accuracy: 0.7189
# Epoch 3/10
# 36/36 [==============================] - 3s 75ms/step - loss: 0.5707 - accuracy: 0.7734 - val_loss: 0.4458 - val_accuracy: 0.8043
# Epoch 4/10
# 36/36 [==============================] - 2s 59ms/step - loss: 0.3482 - accuracy: 0.8537 - val_loss: 0.3373 - val_accuracy: 0.8505
# Epoch 5/10
# 36/36 [==============================] - 2s 59ms/step - loss: 0.2711 - accuracy: 0.8867 - val_loss: 0.3330 - val_accuracy: 0.8648
# Epoch 6/10
# 36/36 [==============================] - 2s 61ms/step - loss: 0.2638 - accuracy: 0.8822 - val_loss: 0.2878 - val_accuracy: 0.8790
# Epoch 7/10
# 36/36 [==============================] - 2s 58ms/step - loss: 0.2474 - accuracy: 0.9010 - val_loss: 0.2829 - val_accuracy: 0.8861
# Epoch 8/10
# 36/36 [==============================] - 2s 63ms/step - loss: 0.2375 - accuracy: 0.9063 - val_loss: 0.2763 - val_accuracy: 0.8754
# Epoch 9/10
# 36/36 [==============================] - 2s 60ms/step - loss: 0.2322 - accuracy: 0.9045 - val_loss: 0.2791 - val_accuracy: 0.8754
# Epoch 10/10
# 36/36 [==============================] - 2s 62ms/step - loss: 0.2387 - accuracy: 0.8983 - val_loss: 0.2740 - val_accuracy: 0.8897
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2740 - accuracy: 0.8897
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89       139
#            1       0.92      0.85      0.89       142
#
#     accuracy                           0.89       281
#    macro avg       0.89      0.89      0.89       281
# weighted avg       0.89      0.89      0.89       281
#
# Epoch 1/20
# 36/36 [==============================] - 5s 43ms/step - loss: 0.6942 - accuracy: 0.4835 - val_loss: 0.6928 - val_accuracy: 0.4982
# Epoch 2/20
# 36/36 [==============================] - 1s 19ms/step - loss: 0.6928 - accuracy: 0.4960 - val_loss: 0.6924 - val_accuracy: 0.5018
# Epoch 3/20
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6927 - accuracy: 0.4987 - val_loss: 0.6917 - val_accuracy: 0.6335
# Epoch 4/20
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6911 - accuracy: 0.5593 - val_loss: 0.6905 - val_accuracy: 0.5409
# Epoch 5/20
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6906 - accuracy: 0.5219 - val_loss: 0.6883 - val_accuracy: 0.5374
# Epoch 6/20
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6852 - accuracy: 0.5923 - val_loss: 0.6815 - val_accuracy: 0.6512
# Epoch 7/20
# 36/36 [==============================] - 1s 19ms/step - loss: 0.6692 - accuracy: 0.6610 - val_loss: 0.6521 - val_accuracy: 0.6726
# Epoch 8/20
# 36/36 [==============================] - 1s 24ms/step - loss: 0.5874 - accuracy: 0.7690 - val_loss: 0.4979 - val_accuracy: 0.8149
# Epoch 9/20
# 36/36 [==============================] - 1s 19ms/step - loss: 0.3537 - accuracy: 0.8715 - val_loss: 0.3267 - val_accuracy: 0.8683
# Epoch 10/20
# 36/36 [==============================] - 1s 19ms/step - loss: 0.2738 - accuracy: 0.8965 - val_loss: 0.2881 - val_accuracy: 0.8790
# Epoch 11/20
# 36/36 [==============================] - 1s 19ms/step - loss: 0.2684 - accuracy: 0.8778 - val_loss: 0.2837 - val_accuracy: 0.8826
# Epoch 12/20
# 36/36 [==============================] - 1s 19ms/step - loss: 0.2444 - accuracy: 0.9045 - val_loss: 0.2736 - val_accuracy: 0.8826
# Epoch 13/20
# 36/36 [==============================] - 1s 19ms/step - loss: 0.2447 - accuracy: 0.9045 - val_loss: 0.2722 - val_accuracy: 0.8932
# Epoch 14/20
# 36/36 [==============================] - 1s 26ms/step - loss: 0.2368 - accuracy: 0.9072 - val_loss: 0.2702 - val_accuracy: 0.8932
# Epoch 15/20
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2325 - accuracy: 0.9063 - val_loss: 0.2683 - val_accuracy: 0.8932
# Epoch 16/20
# 36/36 [==============================] - 1s 20ms/step - loss: 0.2304 - accuracy: 0.9072 - val_loss: 0.2694 - val_accuracy: 0.8932
# Epoch 17/20
# 36/36 [==============================] - 1s 19ms/step - loss: 0.2271 - accuracy: 0.9072 - val_loss: 0.2682 - val_accuracy: 0.8932
# Epoch 18/20
# 36/36 [==============================] - 1s 17ms/step - loss: 0.2249 - accuracy: 0.9063 - val_loss: 0.2709 - val_accuracy: 0.8826
# Epoch 19/20
# 36/36 [==============================] - 1s 19ms/step - loss: 0.2473 - accuracy: 0.9054 - val_loss: 0.2695 - val_accuracy: 0.8968
# Epoch 20/20
# 36/36 [==============================] - 1s 18ms/step - loss: 0.2247 - accuracy: 0.9072 - val_loss: 0.2667 - val_accuracy: 0.8932
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2667 - accuracy: 0.8932
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       139
#            1       0.92      0.86      0.89       142
#
#     accuracy                           0.89       281
#    macro avg       0.90      0.89      0.89       281
# weighted avg       0.90      0.89      0.89       281
#
# Epoch 1/20
# 36/36 [==============================] - 15s 129ms/step - loss: 0.6925 - accuracy: 0.5192 - val_loss: 0.6914 - val_accuracy: 0.5979
# Epoch 2/20
# 36/36 [==============================] - 2s 48ms/step - loss: 0.6911 - accuracy: 0.5424 - val_loss: 0.6880 - val_accuracy: 0.6726
# Epoch 3/20
# 36/36 [==============================] - 2s 56ms/step - loss: 0.6829 - accuracy: 0.6655 - val_loss: 0.6703 - val_accuracy: 0.7260
# Epoch 4/20
# 36/36 [==============================] - 2s 46ms/step - loss: 0.6305 - accuracy: 0.7814 - val_loss: 0.5700 - val_accuracy: 0.5765
# Epoch 5/20
# 36/36 [==============================] - 1s 41ms/step - loss: 0.4673 - accuracy: 0.8350 - val_loss: 0.4314 - val_accuracy: 0.8256
# Epoch 6/20
# 36/36 [==============================] - 1s 40ms/step - loss: 0.3334 - accuracy: 0.8778 - val_loss: 0.3407 - val_accuracy: 0.8612
# Epoch 7/20
# 36/36 [==============================] - 2s 44ms/step - loss: 0.2793 - accuracy: 0.8930 - val_loss: 0.3101 - val_accuracy: 0.8683
# Epoch 8/20
# 36/36 [==============================] - 2s 49ms/step - loss: 0.2611 - accuracy: 0.8983 - val_loss: 0.2933 - val_accuracy: 0.8861
# Epoch 9/20
# 36/36 [==============================] - 2s 46ms/step - loss: 0.2503 - accuracy: 0.9010 - val_loss: 0.2830 - val_accuracy: 0.8861
# Epoch 10/20
# 36/36 [==============================] - 2s 56ms/step - loss: 0.2445 - accuracy: 0.9019 - val_loss: 0.2871 - val_accuracy: 0.8754
# Epoch 11/20
# 36/36 [==============================] - 2s 61ms/step - loss: 0.2409 - accuracy: 0.9037 - val_loss: 0.2775 - val_accuracy: 0.8968
# Epoch 12/20
# 36/36 [==============================] - 2s 48ms/step - loss: 0.2370 - accuracy: 0.9019 - val_loss: 0.2721 - val_accuracy: 0.8932
# Epoch 13/20
# 36/36 [==============================] - 2s 50ms/step - loss: 0.2299 - accuracy: 0.9090 - val_loss: 0.2900 - val_accuracy: 0.8683
# Epoch 14/20
# 36/36 [==============================] - 2s 44ms/step - loss: 0.2346 - accuracy: 0.9108 - val_loss: 0.2727 - val_accuracy: 0.8968
# Epoch 15/20
# 36/36 [==============================] - 2s 51ms/step - loss: 0.2322 - accuracy: 0.9063 - val_loss: 0.2731 - val_accuracy: 0.8968
# Epoch 16/20
# 36/36 [==============================] - 2s 49ms/step - loss: 0.2280 - accuracy: 0.9072 - val_loss: 0.2739 - val_accuracy: 0.8719
# Epoch 17/20
# 36/36 [==============================] - 2s 47ms/step - loss: 0.2246 - accuracy: 0.9037 - val_loss: 0.2699 - val_accuracy: 0.8790
# Epoch 18/20
# 36/36 [==============================] - 2s 57ms/step - loss: 0.2235 - accuracy: 0.9081 - val_loss: 0.2777 - val_accuracy: 0.8790
# Epoch 19/20
# 36/36 [==============================] - 2s 49ms/step - loss: 0.2202 - accuracy: 0.9081 - val_loss: 0.2674 - val_accuracy: 0.8897
# Epoch 20/20
# 36/36 [==============================] - 2s 49ms/step - loss: 0.2219 - accuracy: 0.9072 - val_loss: 0.2679 - val_accuracy: 0.8932
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2679 - accuracy: 0.8932
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90       139
#            1       0.92      0.87      0.89       142
#
#     accuracy                           0.89       281
#    macro avg       0.89      0.89      0.89       281
# weighted avg       0.89      0.89      0.89       281
#
# Epoch 1/20
# 36/36 [==============================] - 21s 172ms/step - loss: 0.6926 - accuracy: 0.5219 - val_loss: 0.6909 - val_accuracy: 0.5374
# Epoch 2/20
# 36/36 [==============================] - 2s 66ms/step - loss: 0.6858 - accuracy: 0.5558 - val_loss: 0.6780 - val_accuracy: 0.5801
# Epoch 3/20
# 36/36 [==============================] - 2s 66ms/step - loss: 0.6503 - accuracy: 0.6655 - val_loss: 0.6113 - val_accuracy: 0.7473
# Epoch 4/20
# 36/36 [==============================] - 3s 82ms/step - loss: 0.4820 - accuracy: 0.8287 - val_loss: 0.3667 - val_accuracy: 0.8683
# Epoch 5/20
# 36/36 [==============================] - 3s 71ms/step - loss: 0.3031 - accuracy: 0.8814 - val_loss: 0.3367 - val_accuracy: 0.8754
# Epoch 6/20
# 36/36 [==============================] - 3s 71ms/step - loss: 0.2843 - accuracy: 0.8912 - val_loss: 0.2946 - val_accuracy: 0.8826
# Epoch 7/20
# 36/36 [==============================] - 3s 75ms/step - loss: 0.2719 - accuracy: 0.8831 - val_loss: 0.2916 - val_accuracy: 0.8754
# Epoch 8/20
# 36/36 [==============================] - 3s 92ms/step - loss: 0.2559 - accuracy: 0.8983 - val_loss: 0.2911 - val_accuracy: 0.8754
# Epoch 9/20
# 36/36 [==============================] - 3s 72ms/step - loss: 0.2432 - accuracy: 0.9019 - val_loss: 0.2883 - val_accuracy: 0.8754
# Epoch 10/20
# 36/36 [==============================] - 3s 79ms/step - loss: 0.2405 - accuracy: 0.9045 - val_loss: 0.2811 - val_accuracy: 0.8790
# Epoch 11/20
# 36/36 [==============================] - 3s 74ms/step - loss: 0.2334 - accuracy: 0.9045 - val_loss: 0.2780 - val_accuracy: 0.8790
# Epoch 12/20
# 36/36 [==============================] - 3s 75ms/step - loss: 0.2299 - accuracy: 0.9063 - val_loss: 0.2759 - val_accuracy: 0.8826
# Epoch 13/20
# 36/36 [==============================] - 3s 75ms/step - loss: 0.2368 - accuracy: 0.9010 - val_loss: 0.3112 - val_accuracy: 0.8754
# Epoch 14/20
# 36/36 [==============================] - 3s 93ms/step - loss: 0.2285 - accuracy: 0.9054 - val_loss: 0.2881 - val_accuracy: 0.8861
# Epoch 15/20
# 36/36 [==============================] - 3s 81ms/step - loss: 0.2267 - accuracy: 0.9054 - val_loss: 0.2777 - val_accuracy: 0.8861
# Epoch 16/20
# 36/36 [==============================] - 3s 71ms/step - loss: 0.2238 - accuracy: 0.9037 - val_loss: 0.2803 - val_accuracy: 0.8861
# Epoch 17/20
# 36/36 [==============================] - 2s 69ms/step - loss: 0.2173 - accuracy: 0.9072 - val_loss: 0.2763 - val_accuracy: 0.8861
# Epoch 18/20
# 36/36 [==============================] - 3s 72ms/step - loss: 0.2176 - accuracy: 0.9099 - val_loss: 0.2809 - val_accuracy: 0.8826
# Epoch 19/20
# 36/36 [==============================] - 3s 85ms/step - loss: 0.2158 - accuracy: 0.9090 - val_loss: 0.2830 - val_accuracy: 0.8790
# Epoch 20/20
# 36/36 [==============================] - 3s 73ms/step - loss: 0.2199 - accuracy: 0.9099 - val_loss: 0.2838 - val_accuracy: 0.8826
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2838 - accuracy: 0.8826
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88       139
#            1       0.90      0.86      0.88       142
#
#     accuracy                           0.88       281
#    macro avg       0.88      0.88      0.88       281
# weighted avg       0.88      0.88      0.88       281
#
# Epoch 1/30
# 36/36 [==============================] - 5s 45ms/step - loss: 0.6933 - accuracy: 0.5049 - val_loss: 0.6928 - val_accuracy: 0.5018
# Epoch 2/30
# 36/36 [==============================] - 1s 21ms/step - loss: 0.6930 - accuracy: 0.4987 - val_loss: 0.6928 - val_accuracy: 0.5018
# Epoch 3/30
# 36/36 [==============================] - 1s 21ms/step - loss: 0.6927 - accuracy: 0.5156 - val_loss: 0.6925 - val_accuracy: 0.5125
# Epoch 4/30
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6924 - accuracy: 0.5094 - val_loss: 0.6921 - val_accuracy: 0.5125
# Epoch 5/30
# 36/36 [==============================] - 1s 21ms/step - loss: 0.6922 - accuracy: 0.5085 - val_loss: 0.6916 - val_accuracy: 0.5160
# Epoch 6/30
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6913 - accuracy: 0.5352 - val_loss: 0.6906 - val_accuracy: 0.5516
# Epoch 7/30
# 36/36 [==============================] - 1s 21ms/step - loss: 0.6899 - accuracy: 0.5326 - val_loss: 0.6879 - val_accuracy: 0.5480
# Epoch 8/30
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6850 - accuracy: 0.6673 - val_loss: 0.6781 - val_accuracy: 0.6512
# Epoch 9/30
# 36/36 [==============================] - 1s 20ms/step - loss: 0.6458 - accuracy: 0.7797 - val_loss: 0.5931 - val_accuracy: 0.8363
# Epoch 10/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.4694 - accuracy: 0.8644 - val_loss: 0.3516 - val_accuracy: 0.8897
# Epoch 11/30
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2882 - accuracy: 0.8921 - val_loss: 0.3049 - val_accuracy: 0.8790
# Epoch 12/30
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2767 - accuracy: 0.8930 - val_loss: 0.2878 - val_accuracy: 0.8897
# Epoch 13/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.2576 - accuracy: 0.8992 - val_loss: 0.2830 - val_accuracy: 0.8861
# Epoch 14/30
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2493 - accuracy: 0.8992 - val_loss: 0.2883 - val_accuracy: 0.8826
# Epoch 15/30
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2414 - accuracy: 0.9037 - val_loss: 0.2762 - val_accuracy: 0.8861
# Epoch 16/30
# 36/36 [==============================] - 1s 21ms/step - loss: 0.2403 - accuracy: 0.9019 - val_loss: 0.2731 - val_accuracy: 0.8932
# Epoch 17/30
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2361 - accuracy: 0.9054 - val_loss: 0.2727 - val_accuracy: 0.8932
# Epoch 18/30
# 36/36 [==============================] - 1s 24ms/step - loss: 0.2322 - accuracy: 0.9054 - val_loss: 0.2701 - val_accuracy: 0.8932
# Epoch 19/30
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2308 - accuracy: 0.9081 - val_loss: 0.2689 - val_accuracy: 0.8932
# Epoch 20/30
# 36/36 [==============================] - 1s 25ms/step - loss: 0.2263 - accuracy: 0.9063 - val_loss: 0.2813 - val_accuracy: 0.8790
# Epoch 21/30
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2249 - accuracy: 0.9090 - val_loss: 0.2688 - val_accuracy: 0.8897
# Epoch 22/30
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2249 - accuracy: 0.9063 - val_loss: 0.2688 - val_accuracy: 0.8932
# Epoch 23/30
# 36/36 [==============================] - 1s 34ms/step - loss: 0.2252 - accuracy: 0.9072 - val_loss: 0.2732 - val_accuracy: 0.8897
# Epoch 24/30
# 36/36 [==============================] - 1s 31ms/step - loss: 0.2296 - accuracy: 0.9019 - val_loss: 0.2672 - val_accuracy: 0.8932
# Epoch 25/30
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2219 - accuracy: 0.9045 - val_loss: 0.2682 - val_accuracy: 0.8968
# Epoch 26/30
# 36/36 [==============================] - 1s 21ms/step - loss: 0.2182 - accuracy: 0.9099 - val_loss: 0.2745 - val_accuracy: 0.8897
# Epoch 27/30
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2192 - accuracy: 0.9099 - val_loss: 0.2678 - val_accuracy: 0.8932
# Epoch 28/30
# 36/36 [==============================] - 1s 23ms/step - loss: 0.2212 - accuracy: 0.9063 - val_loss: 0.2698 - val_accuracy: 0.8719
# Epoch 29/30
# 36/36 [==============================] - 1s 22ms/step - loss: 0.2279 - accuracy: 0.9028 - val_loss: 0.2729 - val_accuracy: 0.8897
# Epoch 30/30
# 36/36 [==============================] - 1s 25ms/step - loss: 0.2168 - accuracy: 0.9063 - val_loss: 0.2700 - val_accuracy: 0.8826
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2700 - accuracy: 0.8826
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89       139
#            1       0.94      0.82      0.88       142
#
#     accuracy                           0.88       281
#    macro avg       0.89      0.88      0.88       281
# weighted avg       0.89      0.88      0.88       281
#
# Epoch 1/30
# 36/36 [==============================] - 14s 104ms/step - loss: 0.6928 - accuracy: 0.5138 - val_loss: 0.6922 - val_accuracy: 0.5267
# Epoch 2/30
# 36/36 [==============================] - 2s 48ms/step - loss: 0.6911 - accuracy: 0.5245 - val_loss: 0.6890 - val_accuracy: 0.5623
# Epoch 3/30
# 36/36 [==============================] - 2s 44ms/step - loss: 0.6819 - accuracy: 0.6173 - val_loss: 0.6670 - val_accuracy: 0.7153
# Epoch 4/30
# 36/36 [==============================] - 2s 51ms/step - loss: 0.6177 - accuracy: 0.7681 - val_loss: 0.5362 - val_accuracy: 0.7651
# Epoch 5/30
# 36/36 [==============================] - 2s 59ms/step - loss: 0.4107 - accuracy: 0.8564 - val_loss: 0.3827 - val_accuracy: 0.8292
# Epoch 6/30
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2981 - accuracy: 0.8840 - val_loss: 0.3346 - val_accuracy: 0.8648
# Epoch 7/30
# 36/36 [==============================] - 2s 59ms/step - loss: 0.2605 - accuracy: 0.8947 - val_loss: 0.2872 - val_accuracy: 0.8861
# Epoch 8/30
# 36/36 [==============================] - 2s 43ms/step - loss: 0.2459 - accuracy: 0.9045 - val_loss: 0.2853 - val_accuracy: 0.8897
# Epoch 9/30
# 36/36 [==============================] - 1s 40ms/step - loss: 0.2540 - accuracy: 0.8930 - val_loss: 0.3255 - val_accuracy: 0.8754
# Epoch 10/30
# 36/36 [==============================] - 1s 40ms/step - loss: 0.2412 - accuracy: 0.9063 - val_loss: 0.2791 - val_accuracy: 0.8897
# Epoch 11/30
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2440 - accuracy: 0.9028 - val_loss: 0.2765 - val_accuracy: 0.8897
# Epoch 12/30
# 36/36 [==============================] - 2s 48ms/step - loss: 0.2318 - accuracy: 0.9081 - val_loss: 0.2700 - val_accuracy: 0.8897
# Epoch 13/30
# 36/36 [==============================] - 1s 42ms/step - loss: 0.2298 - accuracy: 0.9072 - val_loss: 0.2665 - val_accuracy: 0.8968
# Epoch 14/30
# 36/36 [==============================] - 1s 40ms/step - loss: 0.2240 - accuracy: 0.9072 - val_loss: 0.3032 - val_accuracy: 0.8754
# Epoch 15/30
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2292 - accuracy: 0.9028 - val_loss: 0.2706 - val_accuracy: 0.8861
# Epoch 16/30
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2228 - accuracy: 0.9090 - val_loss: 0.2743 - val_accuracy: 0.8861
# Epoch 17/30
# 36/36 [==============================] - 2s 45ms/step - loss: 0.2249 - accuracy: 0.9063 - val_loss: 0.2720 - val_accuracy: 0.8897
# Epoch 18/30
# 36/36 [==============================] - 1s 42ms/step - loss: 0.2199 - accuracy: 0.9081 - val_loss: 0.2846 - val_accuracy: 0.8861
# Epoch 19/30
# 36/36 [==============================] - 2s 50ms/step - loss: 0.2224 - accuracy: 0.9099 - val_loss: 0.2696 - val_accuracy: 0.8790
# Epoch 20/30
# 36/36 [==============================] - 2s 43ms/step - loss: 0.2168 - accuracy: 0.9117 - val_loss: 0.2679 - val_accuracy: 0.9004
# Epoch 21/30
# 36/36 [==============================] - 2s 48ms/step - loss: 0.2128 - accuracy: 0.9126 - val_loss: 0.2766 - val_accuracy: 0.8754
# Epoch 22/30
# 36/36 [==============================] - 2s 45ms/step - loss: 0.2197 - accuracy: 0.9081 - val_loss: 0.2684 - val_accuracy: 0.8968
# Epoch 23/30
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2178 - accuracy: 0.9090 - val_loss: 0.2694 - val_accuracy: 0.8932
# Epoch 24/30
# 36/36 [==============================] - 1s 40ms/step - loss: 0.2189 - accuracy: 0.9072 - val_loss: 0.2687 - val_accuracy: 0.8932
# Epoch 25/30
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2144 - accuracy: 0.9090 - val_loss: 0.2708 - val_accuracy: 0.8861
# Epoch 26/30
# 36/36 [==============================] - 1s 40ms/step - loss: 0.2125 - accuracy: 0.9090 - val_loss: 0.2744 - val_accuracy: 0.8932
# Epoch 27/30
# 36/36 [==============================] - 1s 40ms/step - loss: 0.2109 - accuracy: 0.9099 - val_loss: 0.2707 - val_accuracy: 0.8932
# Epoch 28/30
# 36/36 [==============================] - 1s 41ms/step - loss: 0.2090 - accuracy: 0.9117 - val_loss: 0.2759 - val_accuracy: 0.8932
# Epoch 29/30
# 36/36 [==============================] - 2s 44ms/step - loss: 0.2141 - accuracy: 0.9090 - val_loss: 0.2706 - val_accuracy: 0.8826
# Epoch 30/30
# 36/36 [==============================] - 1s 39ms/step - loss: 0.2299 - accuracy: 0.9028 - val_loss: 0.2851 - val_accuracy: 0.8790
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2851 - accuracy: 0.8790
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.89       139
#            1       0.94      0.82      0.87       142
#
#     accuracy                           0.88       281
#    macro avg       0.88      0.88      0.88       281
# weighted avg       0.89      0.88      0.88       281
#
# Epoch 1/30
# 36/36 [==============================] - 23s 193ms/step - loss: 0.6934 - accuracy: 0.5040 - val_loss: 0.6914 - val_accuracy: 0.6584
# Epoch 2/30
# 36/36 [==============================] - 3s 73ms/step - loss: 0.6866 - accuracy: 0.5852 - val_loss: 0.6750 - val_accuracy: 0.7046
# Epoch 3/30
# 36/36 [==============================] - 3s 72ms/step - loss: 0.6227 - accuracy: 0.7065 - val_loss: 0.5399 - val_accuracy: 0.7829
# Epoch 4/30
# 36/36 [==============================] - 3s 76ms/step - loss: 0.4448 - accuracy: 0.8573 - val_loss: 0.4011 - val_accuracy: 0.8256
# Epoch 5/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.3039 - accuracy: 0.8805 - val_loss: 0.3489 - val_accuracy: 0.8541
# Epoch 6/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.2687 - accuracy: 0.8912 - val_loss: 0.3111 - val_accuracy: 0.8719
# Epoch 7/30
# 36/36 [==============================] - 3s 73ms/step - loss: 0.2661 - accuracy: 0.8938 - val_loss: 0.3253 - val_accuracy: 0.8826
# Epoch 8/30
# 36/36 [==============================] - 3s 76ms/step - loss: 0.2514 - accuracy: 0.9028 - val_loss: 0.2947 - val_accuracy: 0.8826
# Epoch 9/30
# 36/36 [==============================] - 3s 81ms/step - loss: 0.2452 - accuracy: 0.9019 - val_loss: 0.2828 - val_accuracy: 0.8932
# Epoch 10/30
# 36/36 [==============================] - 3s 80ms/step - loss: 0.2390 - accuracy: 0.9037 - val_loss: 0.2848 - val_accuracy: 0.8790
# Epoch 11/30
# 36/36 [==============================] - 3s 72ms/step - loss: 0.2362 - accuracy: 0.9063 - val_loss: 0.2914 - val_accuracy: 0.8754
# Epoch 12/30
# 36/36 [==============================] - 3s 79ms/step - loss: 0.2657 - accuracy: 0.8849 - val_loss: 0.2886 - val_accuracy: 0.8790
# Epoch 13/30
# 36/36 [==============================] - 3s 70ms/step - loss: 0.2365 - accuracy: 0.9028 - val_loss: 0.2748 - val_accuracy: 0.8861
# Epoch 14/30
# 36/36 [==============================] - 3s 78ms/step - loss: 0.2258 - accuracy: 0.9108 - val_loss: 0.2768 - val_accuracy: 0.8861
# Epoch 15/30
# 36/36 [==============================] - 3s 75ms/step - loss: 0.2356 - accuracy: 0.9028 - val_loss: 0.2747 - val_accuracy: 0.8861
# Epoch 16/30
# 36/36 [==============================] - 3s 71ms/step - loss: 0.2258 - accuracy: 0.9090 - val_loss: 0.2721 - val_accuracy: 0.8861
# Epoch 17/30
# 36/36 [==============================] - 3s 79ms/step - loss: 0.2244 - accuracy: 0.9081 - val_loss: 0.3011 - val_accuracy: 0.8754
# Epoch 18/30
# 36/36 [==============================] - 3s 71ms/step - loss: 0.2318 - accuracy: 0.9010 - val_loss: 0.3157 - val_accuracy: 0.8719
# Epoch 19/30
# 36/36 [==============================] - 2s 69ms/step - loss: 0.2341 - accuracy: 0.8876 - val_loss: 0.2808 - val_accuracy: 0.8826
# Epoch 20/30
# 36/36 [==============================] - 3s 73ms/step - loss: 0.2204 - accuracy: 0.9090 - val_loss: 0.2897 - val_accuracy: 0.8754
# Epoch 21/30
# 36/36 [==============================] - 3s 73ms/step - loss: 0.2192 - accuracy: 0.9063 - val_loss: 0.2751 - val_accuracy: 0.8790
# Epoch 22/30
# 36/36 [==============================] - 3s 74ms/step - loss: 0.2163 - accuracy: 0.9090 - val_loss: 0.2731 - val_accuracy: 0.8790
# Epoch 23/30
# 36/36 [==============================] - 3s 71ms/step - loss: 0.2153 - accuracy: 0.9081 - val_loss: 0.2692 - val_accuracy: 0.8932
# Epoch 24/30
# 36/36 [==============================] - 3s 79ms/step - loss: 0.2186 - accuracy: 0.9054 - val_loss: 0.2683 - val_accuracy: 0.8932
# Epoch 25/30
# 36/36 [==============================] - 3s 71ms/step - loss: 0.2121 - accuracy: 0.9099 - val_loss: 0.2765 - val_accuracy: 0.8826
# Epoch 26/30
# 36/36 [==============================] - 2s 68ms/step - loss: 0.2215 - accuracy: 0.9037 - val_loss: 0.2750 - val_accuracy: 0.8897
# Epoch 27/30
# 36/36 [==============================] - 2s 68ms/step - loss: 0.2180 - accuracy: 0.9010 - val_loss: 0.2722 - val_accuracy: 0.8790
# Epoch 28/30
# 36/36 [==============================] - 2s 70ms/step - loss: 0.2129 - accuracy: 0.9099 - val_loss: 0.2688 - val_accuracy: 0.8790
# Epoch 29/30
# 36/36 [==============================] - 3s 83ms/step - loss: 0.2106 - accuracy: 0.9099 - val_loss: 0.2719 - val_accuracy: 0.8897
# Epoch 30/30
# 36/36 [==============================] - 3s 74ms/step - loss: 0.2170 - accuracy: 0.9054 - val_loss: 0.2765 - val_accuracy: 0.8754
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2765 - accuracy: 0.8754
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.88       139
#            1       0.96      0.79      0.86       142
#
#     accuracy                           0.88       281
#    macro avg       0.89      0.88      0.87       281
# weighted avg       0.89      0.88      0.87       281

# %%
output
# Out:
# {0: {'batch': 32,
#   'epoch': 10,
#   'num_of_layer': 1,
#   'acc': [0.4747757613658905, 0.854092538356781],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.89      0.81      0.85       139\n           1       0.83      0.90      0.86       142\n\n    accuracy                           0.85       281\n   macro avg       0.86      0.85      0.85       281\nweighted avg       0.86      0.85      0.85       281\n'},
#  1: {'batch': 32,
#   'epoch': 10,
#   'num_of_layer': 3,
#   'acc': [0.26362287998199463, 0.8932384252548218],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.87      0.92      0.90       139\n           1       0.92      0.87      0.89       142\n\n    accuracy                           0.89       281\n   macro avg       0.89      0.89      0.89       281\nweighted avg       0.89      0.89      0.89       281\n'},
#  2: {'batch': 32,
#   'epoch': 10,
#   'num_of_layer': 5,
#   'acc': [0.273969441652298, 0.8896797299385071],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.86      0.93      0.89       139\n           1       0.92      0.85      0.89       142\n\n    accuracy                           0.89       281\n   macro avg       0.89      0.89      0.89       281\nweighted avg       0.89      0.89      0.89       281\n'},
#  3: {'batch': 32,
#   'epoch': 20,
#   'num_of_layer': 1,
#   'acc': [0.2666623294353485, 0.8932384252548218],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.87      0.93      0.90       139\n           1       0.92      0.86      0.89       142\n\n    accuracy                           0.89       281\n   macro avg       0.90      0.89      0.89       281\nweighted avg       0.90      0.89      0.89       281\n'},
#  4: {'batch': 32,
#   'epoch': 20,
#   'num_of_layer': 3,
#   'acc': [0.2678942084312439, 0.8932384252548218],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.87      0.92      0.90       139\n           1       0.92      0.87      0.89       142\n\n    accuracy                           0.89       281\n   macro avg       0.89      0.89      0.89       281\nweighted avg       0.89      0.89      0.89       281\n'},
#  5: {'batch': 32,
#   'epoch': 20,
#   'num_of_layer': 5,
#   'acc': [0.2838257849216461, 0.8825622797012329],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.86      0.91      0.88       139\n           1       0.90      0.86      0.88       142\n\n    accuracy                           0.88       281\n   macro avg       0.88      0.88      0.88       281\nweighted avg       0.88      0.88      0.88       281\n'},
#  6: {'batch': 32,
#   'epoch': 30,
#   'num_of_layer': 1,
#   'acc': [0.2700011134147644, 0.8825622797012329],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.84      0.95      0.89       139\n           1       0.94      0.82      0.88       142\n\n    accuracy                           0.88       281\n   macro avg       0.89      0.88      0.88       281\nweighted avg       0.89      0.88      0.88       281\n'},
#  7: {'batch': 32,
#   'epoch': 30,
#   'num_of_layer': 3,
#   'acc': [0.2850791811943054, 0.8790035843849182],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.83      0.94      0.89       139\n           1       0.94      0.82      0.87       142\n\n    accuracy                           0.88       281\n   macro avg       0.88      0.88      0.88       281\nweighted avg       0.89      0.88      0.88       281\n'},
#  8: {'batch': 32,
#   'epoch': 30,
#   'num_of_layer': 5,
#   'acc': [0.2764834463596344, 0.8754448294639587],
#   'cm': '              precision    recall  f1-score   support\n\n           0       0.82      0.96      0.88       139\n           1       0.96      0.79      0.86       142\n\n    accuracy                           0.88       281\n   macro avg       0.89      0.88      0.87       281\nweighted avg       0.89      0.88      0.87       281\n'}}

# %%
import json
json_object = json.dumps(output, indent = 4)
with open('model_v0.0.0_gru_dense.json', 'a') as fp:
    fp.write(json_object)
